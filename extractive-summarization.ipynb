# %% [markdown]
# > This is a rework of my group task during Natural Language Processing class in 2022.

# %% [markdown]
# > Goal(s):
# - to construct an extractive text summarization by scratch.

# %% [markdown]
# > Reference(s):
# 1.  https://klu.ai/glossary/rouge-score
# 2.  https://dev.to/aws-builders/mastering-rouge-matrix-your-guide-to-large-language-model-evaluation-for-summarization-with-examples-jjg

# %% [markdown]
# # Import Essentials

# %% [markdown]
# ## Library

# %%
import spacy
import contractions

from string import punctuation
from spacy.lang.en.stop_words import STOP_WORDS
from rouge import Rouge

# %% [markdown]
# ## Data

# %% [markdown]
# > Dataset is obtained from this link:
# https://deepakchopra.medium.com/where-do-we-go-after-we-die-957927200c98

# %%
text = """
One of the main reasons that any religion or spiritual tradition exists is to reassure us about dying. Fear of dying is universal but hidden from view in daily life. Religion and spirituality offer hope that this fear is baseless. Something happens after death — this is the primary message — and this something is good, or at least it is better than nothing.

Despite all of its advances, science has stripped away any reassurances about life after death, and most people in the modern world accept the scientific model. In doing so it logically follows that when the physical body dies, in all likelihood the immaterial aspects of being human — mind soul, memory personality, thoughts, feelings, etc. — are extinguished at the same time.

What this set of beliefs doesn’t offer is proof, in the form of facts, data, information, and so on. In place of religious certainty, modern people face death, not only with fear, doubt, dread, and foreboding but without a shred of empirical evidence about what happens after death. The reason that we casually believe that life ends with nothing isn’t because that’s true. Nothing is simply the absence of facts. When facts end, science has nothing to say.

If you follow this train of thought, both worldviews, the religious/spiritual and the scientific, amount to stories built around assumptions that can’t be proven. When you ask, “Where do we go after we die?” the two main stories — we go to heaven/hell or we vanish into a cloud of atoms and energy waves — are hollow. They confront a mystery that refuses to reveal its secrets.

Where this leaves us is really where we begin, with the individual knowing that death is inevitable but leading a life dedicated to avoiding that fact. Fear of death isn’t necessary. At worst, we go to sleep just as we do every night, and going to sleep isn’t fearful. “I’ll know what happens when it happens” is a good working attitude, but let’s see if there is a better way.

A better way is hinted at in T.S. Eliot’s famous line of poetry, “In my end is my beginning.” This isn’t a religious or mystical statement, although Eliot was deeply religious. What these words mean is true for everyone, atheists and believers alike.

You can’t know how things end until you know how they began.

This looks like a simple statement of cause and effect. If you observe that putting a jar upside down over a candle makes the flame go out, you cannot explain this until you know the laws of chemistry, which reveals that fire needs oxygen to keep going. Use up the oxygen, and the flame goes out.

But there’s a deeper meaning to “You can’t know how things end until you know how they began.” What really matters about death is the survival of consciousness. We observe the flame (the physical body) go out (die), but the mystery revolves around what happens to the non-physical part of ourselves. The things previously listed — mind soul, memory, personality, thoughts, feelings, etc. — are all experiences in consciousness.

No matter how unique anyone’s life is, consciousness brings every human being together in the same place. Life is experienced in consciousness. Therefore, if we know how consciousness begins, we know how it ends. The opposite is also true. If we don’t know how consciousness begins, we can’t possibly know how (or if) it ends.

Suddenly there is an opening for a true revelation. If consciousness has no beginning, then it has no end. In other words, the cause-and-effect model doesn’t work when it comes to consciousness. It can only be explained as existing on its own, independent of everything that does obey the rule of cause and effect.

Can anything really be outside the realm of cause and effect? Absolutely. The universe sprang from a state preceding the Big Bang that offers no clue about matter, energy, space, or time. Without those things, there is no cause and effect. At the smallest scale of nature, the quantum field creates the physical universe through ripples of potential that emerge as subatomic particles and energy waves. There is no cause for this to happen; it just does. Existence has no cause, an obvious fact once you think about it.

The New Age phrase, “Be here now,” isn’t a goal. You cannot help but be here now, since that’s the definition of existence. There are more controversial examples of things that have no cause. Many of your thoughts aren’t caused by the thoughts that preceded them. Thoughts spring up unpredictably from a state that isn’t a thought. It is a silent domain of possibilities.

Here we are at the crux of the answer. If you don’t know how thoughts arise from total silence, you can’t possibly know how or if thoughts end. You already rely on the domain of silent, invisible possibilities all the time. You fetch memories from this domain, along with your vocabulary, your next desire, and your identity, which is nothing more than a constant process of filing away the experiences you identify with, calling them “me.”

The nice thing about existence is that it can be relied upon even when you have no idea where it came from. “To be or not to be” is the wrong question. We are, period. Packaged in with being here now is consciousness. In a basic, irrefutable way, existence and consciousness go together. They are our home. We didn’t invent or create this home. It is our beginning and therefore our end, wrapped into one.

Except that the words “beginning” and “end” are deceptive. There’s no reason to assume that existence had a beginning. Whatever you imagine as non-existence is a concept, and concepts, being mind-made, exist. Trying to nullify existence becomes circular. We are all at home here and now. We couldn’t be conscious without consciousness, the infinite, causeless, invisible, inconceivable origin of everything.

Where do we go after we die? Nowhere in physical terms. We never leave home because there’s no alternative. Non-existence is a fantasy born of fear. I realize that making existence the same as consciousness sounds alien. I’ve tried to state the argument in simple statements that anyone is free to ponder. The answer has to be personal. You have to look at what life is, here and now, to gain anything like a stable set of conclusions. Explore what it is like to be at home, and you will realize that you can never leave home. A new worldview emerges if you look deep enough.
"""

# %%
len(text)
# Out:
# 6372

# %% [markdown]
# # Data Preprocessing

# %% [markdown]
# > Extractive summarization involves summarizing an article by identifying key sentences or phrases from the original text and assembling these portions to create a shorter version. The extracted sentences are then used to produce a summary.

# %% [markdown]
# ## Expand Contractions

# %%
def expand_contractions(text):
  contractions_expanded = []
  for i in text.split():
    contractions_expanded.append(contractions.fix(i))
  contractions_expanded = ' '.join(contractions_expanded)
  return contractions_expanded

# %%
print("\033[91mBEFORE: ")
text
# Out:
# BEFORE:
# '\nOne of the main reasons that any religion or spiritual tradition exists is to reassure us about dying. Fear of dying is universal but hidden from view in daily life. Religion and spirituality offer hope that this fear is baseless. Something happens after death — this is the primary message — and this something is good, or at least it is better than nothing.\n\nDespite all of its advances, science has stripped away any reassurances about life after death, and most people in the modern world accept the scientific model. In doing so it logically follows that when the physical body dies, in all likelihood the immaterial aspects of being human — mind soul, memory personality, thoughts, feelings, etc. — are extinguished at the same time.\n\nWhat this set of beliefs doesn’t offer is proof, in the form of facts, data, information, and so on. In place of religious certainty, modern people face death, not only with fear, doubt, dread, and foreboding but without a shred of empirical evidence about what happens after death. The reason that we casually believe that life ends with nothing isn’t because that’s true. Nothing is simply the absence of facts. When facts end, science has nothing to say.\n\nIf you follow this train of thought, both worldviews, the religious/spiritual and the scientific, amount to stories built around assumptions that can’t be proven. When you ask, “Where do we go after we die?” the two main stories — we go to heaven/hell or we vanish into a cloud of atoms and energy waves — are hollow. They confront a mystery that refuses to reveal its secrets.\n\nWhere this leaves us is really where we begin, with the individual knowing that death is inevitable but leading a life dedicated to avoiding that fact. Fear of death isn’t necessary. At worst, we go to sleep just as we do every night, and going to sleep isn’t fearful. “I’ll know what happens when it happens” is a good working attitude, but let’s see if there is a better way.\n\nA better way is hinted at in T.S. Eliot’s famous line of poetry, “In my end is my beginning.” This isn’t a religious or mystical statement, although Eliot was deeply religious. What these words mean is true for everyone, atheists and believers alike.\n\nYou can’t know how things end until you know how they began.\n\nThis looks like a simple statement of cause and effect. If you observe that putting a jar upside down over a candle makes the flame go out, you cannot explain this until you know the laws of chemistry, which reveals that fire needs oxygen to keep going. Use up the oxygen, and the flame goes out.\n\nBut there’s a deeper meaning to “You can’t know how things end until you know how they began.” What really matters about death is the survival of consciousness. We observe the flame (the physical body) go out (die), but the mystery revolves around what happens to the non-physical part of ourselves. The things previously listed — mind soul, memory, personality, thoughts, feelings, etc. — are all experiences in consciousness.\n\nNo matter how unique anyone’s life is, consciousness brings every human being together in the same place. Life is experienced in consciousness. Therefore, if we know how consciousness begins, we know how it ends. The opposite is also true. If we don’t know how consciousness begins, we can’t possibly know how (or if) it ends.\n\nSuddenly there is an opening for a true revelation. If consciousness has no beginning, then it has no end. In other words, the cause-and-effect model doesn’t work when it comes to consciousness. It can only be explained as existing on its own, independent of everything that does obey the rule of cause and effect.\n\nCan anything really be outside the realm of cause and effect? Absolutely. The universe sprang from a state preceding the Big Bang that offers no clue about matter, energy, space, or time. Without those things, there is no cause and effect. At the smallest scale of nature, the quantum field creates the physical universe through rip ...

# %%
print("\033[92mAFTER: ")
processed_text = expand_contractions(text)
processed_text
# Out:
# AFTER:
# 'One of the main reasons that any religion or spiritual tradition exists is to reassure us about dying. Fear of dying is universal but hidden from view in daily life. Religion and spirituality offer hope that this fear is baseless. Something happens after death — this is the primary message — and this something is good, or at least it is better than nothing. Despite all of its advances, science has stripped away any reassurances about life after death, and most people in the modern world accept the scientific model. In doing so it logically follows that when the physical body dies, in all likelihood the immaterial aspects of being human — mind soul, memory personality, thoughts, feelings, etc. — are extinguished at the same time. What this set of beliefs does not offer is proof, in the form of facts, data, information, and so on. In place of religious certainty, modern people face death, not only with fear, doubt, dread, and foreboding but without a shred of empirical evidence about what happens after death. The reason that we casually believe that life ends with nothing is not because that is true. Nothing is simply the absence of facts. When facts end, science has nothing to say. If you follow this train of thought, both worldviews, the religious/spiritual and the scientific, amount to stories built around assumptions that cannot be proven. When you ask, “Where do we go after we die?” the two main stories — we go to heaven/hell or we vanish into a cloud of atoms and energy waves — are hollow. They confront a mystery that refuses to reveal its secrets. Where this leaves us is really where we begin, with the individual knowing that death is inevitable but leading a life dedicated to avoiding that fact. Fear of death is not necessary. At worst, we go to sleep just as we do every night, and going to sleep is not fearful. “I will know what happens when it happens” is a good working attitude, but let us see if there is a better way. A better way is hinted at in T.S. Eliot’s famous line of poetry, “In my end is my beginning.” This is not a religious or mystical statement, although Eliot was deeply religious. What these words mean is true for everyone, atheists and believers alike. You cannot know how things end until you know how they began. This looks like a simple statement of because and effect. If you observe that putting a jar upside down over a candle makes the flame go out, you cannot explain this until you know the laws of chemistry, which reveals that fire needs oxygen to keep going. Use up the oxygen, and the flame goes out. But there is a deeper meaning to “You cannot know how things end until you know how they began.” What really matters about death is the survival of consciousness. We observe the flame (the physical body) go out (die), but the mystery revolves around what happens to the non-physical part of ourselves. The things previously listed — mind soul, memory, personality, thoughts, feelings, etc. — are all experiences in consciousness. No matter how unique anyone’s life is, consciousness brings every human being together in the same place. Life is experienced in consciousness. Therefore, if we know how consciousness begins, we know how it ends. The opposite is also true. If we do not know how consciousness begins, we cannot possibly know how (or if) it ends. Suddenly there is an opening for a true revelation. If consciousness has no beginning, then it has no end. In other words, the because-and-effect model does not work when it comes to consciousness. It can only be explained as existing on its own, independent of everything that does obey the rule of because and effect. Can anything really be outside the realm of because and effect? Absolutely. The universe sprang from a state preceding the Big Bang that offers no clue about matter, energy, space, or time. Without those things, there is no because and effect. At the smallest scale of nature, the quantum field creates the physical universe through ripples of p ...

# %% [markdown]
# ## Punctuations Removal

# %%
punctuation += '—'
punctuation += '“”'
punctuation += '‘’'

# %%
punctuation
# Out:
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~—“”‘’'

# %%
def punctuations_removal(text):
  punctuations_removed = []
  for i in text:
    if i not in punctuation:
      punctuations_removed.append(i)
    elif i == '-':
      punctuations_removed.append(' ')
  punctuations_removed = ''.join(punctuations_removed)
  return punctuations_removed

# %%
print("\033[91mBEFORE: ")
processed_text
# Out:
# BEFORE:
# 'One of the main reasons that any religion or spiritual tradition exists is to reassure us about dying. Fear of dying is universal but hidden from view in daily life. Religion and spirituality offer hope that this fear is baseless. Something happens after death — this is the primary message — and this something is good, or at least it is better than nothing. Despite all of its advances, science has stripped away any reassurances about life after death, and most people in the modern world accept the scientific model. In doing so it logically follows that when the physical body dies, in all likelihood the immaterial aspects of being human — mind soul, memory personality, thoughts, feelings, etc. — are extinguished at the same time. What this set of beliefs does not offer is proof, in the form of facts, data, information, and so on. In place of religious certainty, modern people face death, not only with fear, doubt, dread, and foreboding but without a shred of empirical evidence about what happens after death. The reason that we casually believe that life ends with nothing is not because that is true. Nothing is simply the absence of facts. When facts end, science has nothing to say. If you follow this train of thought, both worldviews, the religious/spiritual and the scientific, amount to stories built around assumptions that cannot be proven. When you ask, “Where do we go after we die?” the two main stories — we go to heaven/hell or we vanish into a cloud of atoms and energy waves — are hollow. They confront a mystery that refuses to reveal its secrets. Where this leaves us is really where we begin, with the individual knowing that death is inevitable but leading a life dedicated to avoiding that fact. Fear of death is not necessary. At worst, we go to sleep just as we do every night, and going to sleep is not fearful. “I will know what happens when it happens” is a good working attitude, but let us see if there is a better way. A better way is hinted at in T.S. Eliot’s famous line of poetry, “In my end is my beginning.” This is not a religious or mystical statement, although Eliot was deeply religious. What these words mean is true for everyone, atheists and believers alike. You cannot know how things end until you know how they began. This looks like a simple statement of because and effect. If you observe that putting a jar upside down over a candle makes the flame go out, you cannot explain this until you know the laws of chemistry, which reveals that fire needs oxygen to keep going. Use up the oxygen, and the flame goes out. But there is a deeper meaning to “You cannot know how things end until you know how they began.” What really matters about death is the survival of consciousness. We observe the flame (the physical body) go out (die), but the mystery revolves around what happens to the non-physical part of ourselves. The things previously listed — mind soul, memory, personality, thoughts, feelings, etc. — are all experiences in consciousness. No matter how unique anyone’s life is, consciousness brings every human being together in the same place. Life is experienced in consciousness. Therefore, if we know how consciousness begins, we know how it ends. The opposite is also true. If we do not know how consciousness begins, we cannot possibly know how (or if) it ends. Suddenly there is an opening for a true revelation. If consciousness has no beginning, then it has no end. In other words, the because-and-effect model does not work when it comes to consciousness. It can only be explained as existing on its own, independent of everything that does obey the rule of because and effect. Can anything really be outside the realm of because and effect? Absolutely. The universe sprang from a state preceding the Big Bang that offers no clue about matter, energy, space, or time. Without those things, there is no because and effect. At the smallest scale of nature, the quantum field creates the physical universe through ripples of p ...

# %%
print("\033[92mAFTER: ")
processed_text = punctuations_removal(processed_text)
processed_text
# Out:
# AFTER:
# 'One of the main reasons that any religion or spiritual tradition exists is to reassure us about dying Fear of dying is universal but hidden from view in daily life Religion and spirituality offer hope that this fear is baseless Something happens after death  this is the primary message  and this something is good or at least it is better than nothing Despite all of its advances science has stripped away any reassurances about life after death and most people in the modern world accept the scientific model In doing so it logically follows that when the physical body dies in all likelihood the immaterial aspects of being human  mind soul memory personality thoughts feelings etc  are extinguished at the same time What this set of beliefs does not offer is proof in the form of facts data information and so on In place of religious certainty modern people face death not only with fear doubt dread and foreboding but without a shred of empirical evidence about what happens after death The reason that we casually believe that life ends with nothing is not because that is true Nothing is simply the absence of facts When facts end science has nothing to say If you follow this train of thought both worldviews the religiousspiritual and the scientific amount to stories built around assumptions that cannot be proven When you ask Where do we go after we die the two main stories  we go to heavenhell or we vanish into a cloud of atoms and energy waves  are hollow They confront a mystery that refuses to reveal its secrets Where this leaves us is really where we begin with the individual knowing that death is inevitable but leading a life dedicated to avoiding that fact Fear of death is not necessary At worst we go to sleep just as we do every night and going to sleep is not fearful I will know what happens when it happens is a good working attitude but let us see if there is a better way A better way is hinted at in TS Eliots famous line of poetry In my end is my beginning This is not a religious or mystical statement although Eliot was deeply religious What these words mean is true for everyone atheists and believers alike You cannot know how things end until you know how they began This looks like a simple statement of because and effect If you observe that putting a jar upside down over a candle makes the flame go out you cannot explain this until you know the laws of chemistry which reveals that fire needs oxygen to keep going Use up the oxygen and the flame goes out But there is a deeper meaning to You cannot know how things end until you know how they began What really matters about death is the survival of consciousness We observe the flame the physical body go out die but the mystery revolves around what happens to the non physical part of ourselves The things previously listed  mind soul memory personality thoughts feelings etc  are all experiences in consciousness No matter how unique anyones life is consciousness brings every human being together in the same place Life is experienced in consciousness Therefore if we know how consciousness begins we know how it ends The opposite is also true If we do not know how consciousness begins we cannot possibly know how or if it ends Suddenly there is an opening for a true revelation If consciousness has no beginning then it has no end In other words the because and effect model does not work when it comes to consciousness It can only be explained as existing on its own independent of everything that does obey the rule of because and effect Can anything really be outside the realm of because and effect Absolutely The universe sprang from a state preceding the Big Bang that offers no clue about matter energy space or time Without those things there is no because and effect At the smallest scale of nature the quantum field creates the physical universe through ripples of potential that emerge as subatomic particles and energy waves There is no because for this to happen it just does Existence  ...

# %% [markdown]
# ## Extra Space Removal

# %%
def extraspace_removal(text):
  extraspace_removed = " ".join(text.split())
  return extraspace_removed

# %%
print("\033[91mBEFORE: ")
processed_text
# Out:
# BEFORE:
# 'One of the main reasons that any religion or spiritual tradition exists is to reassure us about dying Fear of dying is universal but hidden from view in daily life Religion and spirituality offer hope that this fear is baseless Something happens after death  this is the primary message  and this something is good or at least it is better than nothing Despite all of its advances science has stripped away any reassurances about life after death and most people in the modern world accept the scientific model In doing so it logically follows that when the physical body dies in all likelihood the immaterial aspects of being human  mind soul memory personality thoughts feelings etc  are extinguished at the same time What this set of beliefs does not offer is proof in the form of facts data information and so on In place of religious certainty modern people face death not only with fear doubt dread and foreboding but without a shred of empirical evidence about what happens after death The reason that we casually believe that life ends with nothing is not because that is true Nothing is simply the absence of facts When facts end science has nothing to say If you follow this train of thought both worldviews the religiousspiritual and the scientific amount to stories built around assumptions that cannot be proven When you ask Where do we go after we die the two main stories  we go to heavenhell or we vanish into a cloud of atoms and energy waves  are hollow They confront a mystery that refuses to reveal its secrets Where this leaves us is really where we begin with the individual knowing that death is inevitable but leading a life dedicated to avoiding that fact Fear of death is not necessary At worst we go to sleep just as we do every night and going to sleep is not fearful I will know what happens when it happens is a good working attitude but let us see if there is a better way A better way is hinted at in TS Eliots famous line of poetry In my end is my beginning This is not a religious or mystical statement although Eliot was deeply religious What these words mean is true for everyone atheists and believers alike You cannot know how things end until you know how they began This looks like a simple statement of because and effect If you observe that putting a jar upside down over a candle makes the flame go out you cannot explain this until you know the laws of chemistry which reveals that fire needs oxygen to keep going Use up the oxygen and the flame goes out But there is a deeper meaning to You cannot know how things end until you know how they began What really matters about death is the survival of consciousness We observe the flame the physical body go out die but the mystery revolves around what happens to the non physical part of ourselves The things previously listed  mind soul memory personality thoughts feelings etc  are all experiences in consciousness No matter how unique anyones life is consciousness brings every human being together in the same place Life is experienced in consciousness Therefore if we know how consciousness begins we know how it ends The opposite is also true If we do not know how consciousness begins we cannot possibly know how or if it ends Suddenly there is an opening for a true revelation If consciousness has no beginning then it has no end In other words the because and effect model does not work when it comes to consciousness It can only be explained as existing on its own independent of everything that does obey the rule of because and effect Can anything really be outside the realm of because and effect Absolutely The universe sprang from a state preceding the Big Bang that offers no clue about matter energy space or time Without those things there is no because and effect At the smallest scale of nature the quantum field creates the physical universe through ripples of potential that emerge as subatomic particles and energy waves There is no because for this to happen it just does Existence  ...

# %%
print("\033[92mAFTER: ")
processed_text = extraspace_removal(processed_text)
processed_text
# Out:
# AFTER:
# 'One of the main reasons that any religion or spiritual tradition exists is to reassure us about dying Fear of dying is universal but hidden from view in daily life Religion and spirituality offer hope that this fear is baseless Something happens after death this is the primary message and this something is good or at least it is better than nothing Despite all of its advances science has stripped away any reassurances about life after death and most people in the modern world accept the scientific model In doing so it logically follows that when the physical body dies in all likelihood the immaterial aspects of being human mind soul memory personality thoughts feelings etc are extinguished at the same time What this set of beliefs does not offer is proof in the form of facts data information and so on In place of religious certainty modern people face death not only with fear doubt dread and foreboding but without a shred of empirical evidence about what happens after death The reason that we casually believe that life ends with nothing is not because that is true Nothing is simply the absence of facts When facts end science has nothing to say If you follow this train of thought both worldviews the religiousspiritual and the scientific amount to stories built around assumptions that cannot be proven When you ask Where do we go after we die the two main stories we go to heavenhell or we vanish into a cloud of atoms and energy waves are hollow They confront a mystery that refuses to reveal its secrets Where this leaves us is really where we begin with the individual knowing that death is inevitable but leading a life dedicated to avoiding that fact Fear of death is not necessary At worst we go to sleep just as we do every night and going to sleep is not fearful I will know what happens when it happens is a good working attitude but let us see if there is a better way A better way is hinted at in TS Eliots famous line of poetry In my end is my beginning This is not a religious or mystical statement although Eliot was deeply religious What these words mean is true for everyone atheists and believers alike You cannot know how things end until you know how they began This looks like a simple statement of because and effect If you observe that putting a jar upside down over a candle makes the flame go out you cannot explain this until you know the laws of chemistry which reveals that fire needs oxygen to keep going Use up the oxygen and the flame goes out But there is a deeper meaning to You cannot know how things end until you know how they began What really matters about death is the survival of consciousness We observe the flame the physical body go out die but the mystery revolves around what happens to the non physical part of ourselves The things previously listed mind soul memory personality thoughts feelings etc are all experiences in consciousness No matter how unique anyones life is consciousness brings every human being together in the same place Life is experienced in consciousness Therefore if we know how consciousness begins we know how it ends The opposite is also true If we do not know how consciousness begins we cannot possibly know how or if it ends Suddenly there is an opening for a true revelation If consciousness has no beginning then it has no end In other words the because and effect model does not work when it comes to consciousness It can only be explained as existing on its own independent of everything that does obey the rule of because and effect Can anything really be outside the realm of because and effect Absolutely The universe sprang from a state preceding the Big Bang that offers no clue about matter energy space or time Without those things there is no because and effect At the smallest scale of nature the quantum field creates the physical universe through ripples of potential that emerge as subatomic particles and energy waves There is no because for this to happen it just does Existence has no b ...

# %% [markdown]
# ## Tokenizing

# %%
nlp = spacy.load('en_core_web_sm')

# %%
def tokenizing(text):
  segments = nlp(text)
  tokenized_text = []
  for i in segments:
    tokenized_text.append(i)
  return tokenized_text

# %%
processed_text = tokenizing(processed_text)
processed_text
# Out:
# [One,
#  of,
#  the,
#  main,
#  reasons,
#  that,
#  any,
#  religion,
#  or,
#  spiritual,
#  tradition,
#  exists,
#  is,
#  to,
#  reassure,
#  us,
#  about,
#  dying,
#  Fear,
#  of,
#  dying,
#  is,
#  universal,
#  but,
#  hidden,
#  from,
#  view,
#  in,
#  daily,
#  life,
#  Religion,
#  and,
#  spirituality,
#  offer,
#  hope,
#  that,
#  this,
#  fear,
#  is,
#  baseless,
#  Something,
#  happens,
#  after,
#  death,
#  this,
#  is,
#  the,
#  primary,
#  message,
#  and,
#  this,
#  something,
#  is,
#  good,
#  or,
#  at,
#  least,
#  it,
#  is,
#  better,
#  than,
#  nothing,
#  Despite,
#  all,
#  of,
#  its,
#  advances,
#  science,
#  has,
#  stripped,
#  away,
#  any,
#  reassurances,
#  about,
#  life,
#  after,
#  death,
#  and,
#  most,
#  people,
#  in,
#  the,
#  modern,
#  world,
#  accept,
#  the,
#  scientific,
#  model,
#  In,
#  doing,
#  so,
#  it,
#  logically,
#  follows,
#  that,
#  when,
#  the,
#  physical,
#  body,
#  dies,
#  in,
#  all,
#  likelihood,
#  the,
#  immaterial,
#  aspects,
#  of,
#  being,
#  human,
#  mind,
#  soul,
#  memory,
#  personality,
#  thoughts,
#  feelings,
#  etc,
#  are,
#  extinguished,
#  at,
#  the,
#  same,
#  time,
#  What,
#  this,
#  set,
#  of,
#  beliefs,
#  does,
#  not,
#  offer,
#  is,
#  proof,
#  in,
#  the,
#  form,
#  of,
#  facts,
#  data,
#  information,
#  and,
#  so,
#  on,
#  In,
#  place,
#  of,
#  religious,
#  certainty,
#  modern,
#  people,
#  face,
#  death,
#  not,
#  only,
#  with,
#  fear,
#  doubt,
#  dread,
#  and,
#  foreboding,
#  but,
#  without,
#  a,
#  shred,
#  of,
#  empirical,
#  evidence,
#  about,
#  what,
#  happens,
#  after,
#  death,
#  The,
#  reason,
#  that,
#  we,
#  casually,
#  believe,
#  that,
#  life,
#  ends,
#  with,
#  nothing,
#  is,
#  not,
#  because,
#  that,
#  is,
#  true,
#  Nothing,
#  is,
#  simply,
#  the,
#  absence,
#  of,
#  facts,
#  When,
#  facts,
#  end,
#  science,
#  has,
#  nothing,
#  to,
#  say,
#  If,
#  you,
#  follow,
#  this,
#  train,
#  of,
#  thought,
#  both,
#  worldviews,
#  the,
#  religiousspiritual,
#  and,
#  the,
#  scientific,
#  amount,
#  to,
#  stories,
#  built,
#  around,
#  assumptions,
#  that,
#  can,
#  not,
#  be,
#  proven,
#  When,
#  you,
#  ask,
#  Where,
#  do,
#  we,
#  go,
#  after,
#  we,
#  die,
#  the,
#  two,
#  main,
#  stories,
#  we,
#  go,
#  to,
#  heavenhell,
#  or,
#  we,
#  vanish,
#  into,
#  a,
#  cloud,
#  of,
#  atoms,
#  and,
#  energy,
#  waves,
#  are,
#  hollow,
#  They,
#  confront,
#  a,
#  mystery,
#  that,
#  refuses,
#  to,
#  reveal,
#  its,
#  secrets,
#  Where,
#  this,
#  leaves,
#  us,
#  is,
#  really,
#  where,
#  we,
#  begin,
#  with,
#  the,
#  individual,
#  knowing,
#  that,
#  death,
#  is,
#  inevitable,
#  but,
#  leading,
#  a,
#  life,
#  dedicated,
#  to,
#  avoiding,
#  that,
#  fact,
#  Fear,
#  of,
#  death,
#  is,
#  not,
#  necessary,
#  At,
#  worst,
#  we,
#  go,
#  to,
#  sleep,
#  just,
#  as,
#  we,
#  do,
#  every,
#  night,
#  and,
#  going,
#  to,
#  sleep,
#  is,
#  not,
#  fearful,
#  I,
#  will,
#  know,
#  what,
#  happens,
#  when,
#  it,
#  happens,
#  is,
#  a,
#  good,
#  working,
#  attitude,
#  but,
#  let,
#  us,
#  see,
#  if,
#  there,
#  is,
#  a,
#  better,
#  way,
#  A,
#  better,
#  way,
#  is,
#  hinted,
#  at,
#  in,
#  TS,
#  Eliots,
#  famous,
#  line,
#  of,
#  poetry,
#  In,
#  my,
#  end,
#  is,
#  my,
#  beginning,
#  This,
#  is,
#  not,
#  a,
#  religious,
#  or,
#  mystical,
#  statement,
#  although,
#  Eliot,
#  was,
#  deeply,
#  religious,
#  What,
#  these,
#  words,
#  mean,
#  is,
#  true,
#  for,
#  everyone,
#  atheists,
#  and,
#  believers,
#  alike,
#  You,
#  can,
#  not,
#  know,
#  how,
#  things,
#  end,
#  until,
#  you,
#  know,
#  how,
#  they,
#  began,
#  This,
#  looks,
#  like,
#  a,
#  simple,
#  statement,
#  of,
#  because,
#  and,
#  effect,
#  If,
#  you,
#  observe,
#  that,
#  putting,
#  a,
#  jar,
#  upside,
#  down,
#  over,
#  a,
#  candle,
#  makes,
#  the,
#  flame,
#  go,
#  out,
#  you,
#  can,
#  not,
#  explain,
#  this,
#  until,
#  you,
#  know,
#  the,
#  laws,
#  of,
#  chemistry,
#  which,
#  reveals,
#  that,
#  fire,
#  needs,
#  oxygen,
#  to,
#  keep,
#  going,
#  Use,
#  up,
#  the,
#  oxygen,
#  and,
#  the,
#  flame,
#  goes,
#  out,
#  But,
#  there,
#  is,
#  a,
#  deeper,
#  meaning,
#  to,
#  You,
#  can,
#  not,
#  know,
#  how,
#  things,
#  end,
#  until,
#  you,
#  know,
#  how,
#  they,
#  began,
#  What,
#  really,
#  matters,
#  about,
#  death,
#  is,
#  the,
#  survival,
#  of,
#  consciousness,
#  We,
#  observe,
#  the,
#  flame,
#  the,
#  physical,
#  body,
#  go,
#  out,
#  die,
#  but,
#  the,
#  mystery,
#  revolves,
#  around,
#  what,
#  happens,
#  to,
#  the,
#  non,
#  physical,
#  part,
#  of,
#  ourselves,
#  The,
#  things,
#  previously,
#  listed,
#  mind,
#  soul,
#  memory,
#  personality,
#  thoughts,
#  feelings,
#  etc,
#  are,
#  all,
#  experiences,
#  in,
#  consciousness,
#  No,
#  matter,
#  how,
#  unique,
#  anyones,
#  life,
#  is,
#  consciousness,
#  brings,
#  every,
#  human,
#  being,
#  together,
#  in,
#  the,
#  same,
#  place,
#  Life,
#  is,
#  experienced,
#  in,
#  consciousness,
#  Therefore,
#  if,
#  we,
#  know,
#  how,
#  consciousness,
#  begins,
#  we,
#  know,
#  how,
#  it,
#  ends,
#  The,
#  opposite,
#  is,
#  also,
#  true,
#  If,
#  we,
#  do,
#  not,
#  know,
#  how,
#  consciousness,
#  begins,
#  we,
#  can,
#  not,
#  possibly,
#  know,
#  how,
#  or,
#  if,
#  it,
#  ends,
#  Suddenly,
#  there,
#  is,
#  an,
#  opening,
#  for,
#  a,
#  true,
#  revelation,
#  If,
#  consciousness,
#  has,
#  no,
#  beginning,
#  then,
#  it,
#  has,
#  no,
#  end,
#  In,
#  other,
#  words,
#  the,
#  because,
#  and,
#  effect,
#  model,
#  does,
#  not,
#  work,
#  when,
#  it,
#  comes,
#  to,
#  consciousness,
#  It,
#  can,
#  only,
#  be,
#  explained,
#  as,
#  existing,
#  on,
#  its,
#  own,
#  independent,
#  of,
#  everything,
#  that,
#  does,
#  obey,
#  the,
#  rule,
#  of,
#  because,
#  and,
#  effect,
#  Can,
#  anything,
#  really,
#  be,
#  outside,
#  the,
#  realm,
#  of,
#  because,
#  and,
#  effect,
#  Absolutely,
#  The,
#  universe,
#  sprang,
#  from,
#  a,
#  state,
#  preceding,
#  the,
#  Big,
#  Bang,
#  that,
#  offers,
#  no,
#  clue,
#  about,
#  matter,
#  energy,
#  space,
#  or,
#  time,
#  Without,
#  those,
#  things,
#  there,
#  is,
#  no,
#  because,
#  and,
#  effect,
#  At,
#  the,
#  smallest,
#  scale,
#  of,
#  nature,
#  the,
#  quantum,
#  field,
#  creates,
#  the,
#  physical,
#  universe,
#  through,
#  ripples,
#  of,
#  potential,
#  that,
#  emerge,
#  as,
#  subatomic,
#  particles,
#  and,
#  energy,
#  waves,
#  There,
#  is,
#  no,
#  because,
#  for,
#  this,
#  to,
#  happen,
#  it,
#  just,
#  does,
#  Existence,
#  has,
#  no,
#  because,
#  an,
#  obvious,
#  fact,
#  once,
#  you,
#  think,
#  about,
#  it,
#  The,
#  New,
#  Age,
#  phrase,
#  Be,
#  here,
#  now,
#  is,
#  not,
#  a,
#  goal,
#  You,
#  can,
#  not,
#  help,
#  but,
#  be,
#  here,
#  now,
#  since,
#  that,
#  is,
#  the,
#  definition,
#  of,
#  existence,
#  There,
#  are,
#  more,
#  controversial,
#  examples,
#  of,
#  things,
#  that,
#  have,
#  no,
#  because,
#  Many,
#  of,
#  your,
#  thoughts,
#  are,
#  not,
#  caused,
#  by,
#  the,
#  thoughts,
#  that,
#  preceded,
#  them,
#  Thoughts,
#  spring,
#  up,
#  unpredictably,
#  from,
#  a,
#  state,
#  that,
#  is,
#  not,
#  a,
#  thought,
#  It,
#  is,
#  a,
#  silent,
#  domain,
#  of,
#  possibilities,
#  Here,
#  we,
#  are,
#  at,
#  the,
#  crux,
#  of,
#  the,
#  answer,
#  If,
#  you,
#  do,
#  not,
#  know,
#  how,
#  thoughts,
#  arise,
#  from,
#  total,
#  silence,
#  you,
#  can,
#  not,
#  possibly,
#  know,
#  how,
#  or,
#  if,
#  thoughts,
#  end,
#  You,
#  already,
#  rely,
#  on,
#  the,
#  domain,
#  of,
#  silent,
#  invisible,
#  possibilities,
#  all,
#  the,
#  time,
#  You,
#  fetch,
#  memories,
#  from,
#  this,
#  domain,
#  along,
#  with,
#  your,
#  vocabulary,
#  your,
#  next,
#  desire,
#  and,
#  your,
#  identity,
#  which,
#  is,
#  nothing,
#  more,
#  than,
#  a,
#  constant,
#  process,
#  of,
#  filing,
#  away,
#  the,
#  experiences,
#  you,
#  identify,
#  with,
#  calling,
#  them,
#  me,
#  The,
#  nice,
#  thing,
#  about,
#  existence,
#  is,
#  that,
#  it,
#  can,
#  be,
#  relied,
#  upon,
#  even,
#  when,
#  you,
#  have,
#  no,
#  idea,
#  where,
#  it,
#  came,
#  from,
#  To,
#  be,
#  or,
#  not,
#  to,
#  be,
#  is,
#  the,
#  wrong,
#  question,
#  We,
#  are,
#  period,
#  Packaged,
#  in,
#  with,
#  being,
#  here,
#  now,
#  is,
#  consciousness,
#  In,
#  a,
#  basic,
#  irrefutable,
#  way,
#  existence,
#  and,
#  consciousness,
#  go,
#  together,
#  They,
#  are,
#  our,
#  home,
#  We,
#  did,
#  not,
#  invent,
#  or,
#  create,
#  this,
#  home,
#  It,
#  is,
#  our,
#  beginning,
#  and,
#  therefore,
#  our,
#  end,
#  wrapped,
#  into,
#  one,
#  Except,
#  that,
#  the,
#  words,
#  beginning,
#  and,
#  end,
#  are,
#  deceptive,
#  There,
#  is,
#  no,
#  reason,
#  to,
#  assume,
#  that,
#  existence,
#  had,
#  a,
#  beginning,
#  Whatever,
#  you,
#  imagine,
#  as,
#  non,
#  existence,
#  is,
#  a,
#  concept,
#  and,
#  concepts,
#  being,
#  mind,
#  made,
#  exist,
#  Trying,
#  to,
#  nullify,
#  existence,
#  becomes,
#  circular,
#  We,
#  are,
#  all,
#  at,
#  home,
#  here,
#  ...]

# %% [markdown]
# ## Lowercasing

# %%
def lowercasing(text):
  lowercased_text = []
  for i in text:
    lowercased_text.append(i.text.lower())
  return lowercased_text

# %%
processed_text = lowercasing(processed_text)
processed_text
# Out:
# ['one',
#  'of',
#  'the',
#  'main',
#  'reasons',
#  'that',
#  'any',
#  'religion',
#  'or',
#  'spiritual',
#  'tradition',
#  'exists',
#  'is',
#  'to',
#  'reassure',
#  'us',
#  'about',
#  'dying',
#  'fear',
#  'of',
#  'dying',
#  'is',
#  'universal',
#  'but',
#  'hidden',
#  'from',
#  'view',
#  'in',
#  'daily',
#  'life',
#  'religion',
#  'and',
#  'spirituality',
#  'offer',
#  'hope',
#  'that',
#  'this',
#  'fear',
#  'is',
#  'baseless',
#  'something',
#  'happens',
#  'after',
#  'death',
#  'this',
#  'is',
#  'the',
#  'primary',
#  'message',
#  'and',
#  'this',
#  'something',
#  'is',
#  'good',
#  'or',
#  'at',
#  'least',
#  'it',
#  'is',
#  'better',
#  'than',
#  'nothing',
#  'despite',
#  'all',
#  'of',
#  'its',
#  'advances',
#  'science',
#  'has',
#  'stripped',
#  'away',
#  'any',
#  'reassurances',
#  'about',
#  'life',
#  'after',
#  'death',
#  'and',
#  'most',
#  'people',
#  'in',
#  'the',
#  'modern',
#  'world',
#  'accept',
#  'the',
#  'scientific',
#  'model',
#  'in',
#  'doing',
#  'so',
#  'it',
#  'logically',
#  'follows',
#  'that',
#  'when',
#  'the',
#  'physical',
#  'body',
#  'dies',
#  'in',
#  'all',
#  'likelihood',
#  'the',
#  'immaterial',
#  'aspects',
#  'of',
#  'being',
#  'human',
#  'mind',
#  'soul',
#  'memory',
#  'personality',
#  'thoughts',
#  'feelings',
#  'etc',
#  'are',
#  'extinguished',
#  'at',
#  'the',
#  'same',
#  'time',
#  'what',
#  'this',
#  'set',
#  'of',
#  'beliefs',
#  'does',
#  'not',
#  'offer',
#  'is',
#  'proof',
#  'in',
#  'the',
#  'form',
#  'of',
#  'facts',
#  'data',
#  'information',
#  'and',
#  'so',
#  'on',
#  'in',
#  'place',
#  'of',
#  'religious',
#  'certainty',
#  'modern',
#  'people',
#  'face',
#  'death',
#  'not',
#  'only',
#  'with',
#  'fear',
#  'doubt',
#  'dread',
#  'and',
#  'foreboding',
#  'but',
#  'without',
#  'a',
#  'shred',
#  'of',
#  'empirical',
#  'evidence',
#  'about',
#  'what',
#  'happens',
#  'after',
#  'death',
#  'the',
#  'reason',
#  'that',
#  'we',
#  'casually',
#  'believe',
#  'that',
#  'life',
#  'ends',
#  'with',
#  'nothing',
#  'is',
#  'not',
#  'because',
#  'that',
#  'is',
#  'true',
#  'nothing',
#  'is',
#  'simply',
#  'the',
#  'absence',
#  'of',
#  'facts',
#  'when',
#  'facts',
#  'end',
#  'science',
#  'has',
#  'nothing',
#  'to',
#  'say',
#  'if',
#  'you',
#  'follow',
#  'this',
#  'train',
#  'of',
#  'thought',
#  'both',
#  'worldviews',
#  'the',
#  'religiousspiritual',
#  'and',
#  'the',
#  'scientific',
#  'amount',
#  'to',
#  'stories',
#  'built',
#  'around',
#  'assumptions',
#  'that',
#  'can',
#  'not',
#  'be',
#  'proven',
#  'when',
#  'you',
#  'ask',
#  'where',
#  'do',
#  'we',
#  'go',
#  'after',
#  'we',
#  'die',
#  'the',
#  'two',
#  'main',
#  'stories',
#  'we',
#  'go',
#  'to',
#  'heavenhell',
#  'or',
#  'we',
#  'vanish',
#  'into',
#  'a',
#  'cloud',
#  'of',
#  'atoms',
#  'and',
#  'energy',
#  'waves',
#  'are',
#  'hollow',
#  'they',
#  'confront',
#  'a',
#  'mystery',
#  'that',
#  'refuses',
#  'to',
#  'reveal',
#  'its',
#  'secrets',
#  'where',
#  'this',
#  'leaves',
#  'us',
#  'is',
#  'really',
#  'where',
#  'we',
#  'begin',
#  'with',
#  'the',
#  'individual',
#  'knowing',
#  'that',
#  'death',
#  'is',
#  'inevitable',
#  'but',
#  'leading',
#  'a',
#  'life',
#  'dedicated',
#  'to',
#  'avoiding',
#  'that',
#  'fact',
#  'fear',
#  'of',
#  'death',
#  'is',
#  'not',
#  'necessary',
#  'at',
#  'worst',
#  'we',
#  'go',
#  'to',
#  'sleep',
#  'just',
#  'as',
#  'we',
#  'do',
#  'every',
#  'night',
#  'and',
#  'going',
#  'to',
#  'sleep',
#  'is',
#  'not',
#  'fearful',
#  'i',
#  'will',
#  'know',
#  'what',
#  'happens',
#  'when',
#  'it',
#  'happens',
#  'is',
#  'a',
#  'good',
#  'working',
#  'attitude',
#  'but',
#  'let',
#  'us',
#  'see',
#  'if',
#  'there',
#  'is',
#  'a',
#  'better',
#  'way',
#  'a',
#  'better',
#  'way',
#  'is',
#  'hinted',
#  'at',
#  'in',
#  'ts',
#  'eliots',
#  'famous',
#  'line',
#  'of',
#  'poetry',
#  'in',
#  'my',
#  'end',
#  'is',
#  'my',
#  'beginning',
#  'this',
#  'is',
#  'not',
#  'a',
#  'religious',
#  'or',
#  'mystical',
#  'statement',
#  'although',
#  'eliot',
#  'was',
#  'deeply',
#  'religious',
#  'what',
#  'these',
#  'words',
#  'mean',
#  'is',
#  'true',
#  'for',
#  'everyone',
#  'atheists',
#  'and',
#  'believers',
#  'alike',
#  'you',
#  'can',
#  'not',
#  'know',
#  'how',
#  'things',
#  'end',
#  'until',
#  'you',
#  'know',
#  'how',
#  'they',
#  'began',
#  'this',
#  'looks',
#  'like',
#  'a',
#  'simple',
#  'statement',
#  'of',
#  'because',
#  'and',
#  'effect',
#  'if',
#  'you',
#  'observe',
#  'that',
#  'putting',
#  'a',
#  'jar',
#  'upside',
#  'down',
#  'over',
#  'a',
#  'candle',
#  'makes',
#  'the',
#  'flame',
#  'go',
#  'out',
#  'you',
#  'can',
#  'not',
#  'explain',
#  'this',
#  'until',
#  'you',
#  'know',
#  'the',
#  'laws',
#  'of',
#  'chemistry',
#  'which',
#  'reveals',
#  'that',
#  'fire',
#  'needs',
#  'oxygen',
#  'to',
#  'keep',
#  'going',
#  'use',
#  'up',
#  'the',
#  'oxygen',
#  'and',
#  'the',
#  'flame',
#  'goes',
#  'out',
#  'but',
#  'there',
#  'is',
#  'a',
#  'deeper',
#  'meaning',
#  'to',
#  'you',
#  'can',
#  'not',
#  'know',
#  'how',
#  'things',
#  'end',
#  'until',
#  'you',
#  'know',
#  'how',
#  'they',
#  'began',
#  'what',
#  'really',
#  'matters',
#  'about',
#  'death',
#  'is',
#  'the',
#  'survival',
#  'of',
#  'consciousness',
#  'we',
#  'observe',
#  'the',
#  'flame',
#  'the',
#  'physical',
#  'body',
#  'go',
#  'out',
#  'die',
#  'but',
#  'the',
#  'mystery',
#  'revolves',
#  'around',
#  'what',
#  'happens',
#  'to',
#  'the',
#  'non',
#  'physical',
#  'part',
#  'of',
#  'ourselves',
#  'the',
#  'things',
#  'previously',
#  'listed',
#  'mind',
#  'soul',
#  'memory',
#  'personality',
#  'thoughts',
#  'feelings',
#  'etc',
#  'are',
#  'all',
#  'experiences',
#  'in',
#  'consciousness',
#  'no',
#  'matter',
#  'how',
#  'unique',
#  'anyones',
#  'life',
#  'is',
#  'consciousness',
#  'brings',
#  'every',
#  'human',
#  'being',
#  'together',
#  'in',
#  'the',
#  'same',
#  'place',
#  'life',
#  'is',
#  'experienced',
#  'in',
#  'consciousness',
#  'therefore',
#  'if',
#  'we',
#  'know',
#  'how',
#  'consciousness',
#  'begins',
#  'we',
#  'know',
#  'how',
#  'it',
#  'ends',
#  'the',
#  'opposite',
#  'is',
#  'also',
#  'true',
#  'if',
#  'we',
#  'do',
#  'not',
#  'know',
#  'how',
#  'consciousness',
#  'begins',
#  'we',
#  'can',
#  'not',
#  'possibly',
#  'know',
#  'how',
#  'or',
#  'if',
#  'it',
#  'ends',
#  'suddenly',
#  'there',
#  'is',
#  'an',
#  'opening',
#  'for',
#  'a',
#  'true',
#  'revelation',
#  'if',
#  'consciousness',
#  'has',
#  'no',
#  'beginning',
#  'then',
#  'it',
#  'has',
#  'no',
#  'end',
#  'in',
#  'other',
#  'words',
#  'the',
#  'because',
#  'and',
#  'effect',
#  'model',
#  'does',
#  'not',
#  'work',
#  'when',
#  'it',
#  'comes',
#  'to',
#  'consciousness',
#  'it',
#  'can',
#  'only',
#  'be',
#  'explained',
#  'as',
#  'existing',
#  'on',
#  'its',
#  'own',
#  'independent',
#  'of',
#  'everything',
#  'that',
#  'does',
#  'obey',
#  'the',
#  'rule',
#  'of',
#  'because',
#  'and',
#  'effect',
#  'can',
#  'anything',
#  'really',
#  'be',
#  'outside',
#  'the',
#  'realm',
#  'of',
#  'because',
#  'and',
#  'effect',
#  'absolutely',
#  'the',
#  'universe',
#  'sprang',
#  'from',
#  'a',
#  'state',
#  'preceding',
#  'the',
#  'big',
#  'bang',
#  'that',
#  'offers',
#  'no',
#  'clue',
#  'about',
#  'matter',
#  'energy',
#  'space',
#  'or',
#  'time',
#  'without',
#  'those',
#  'things',
#  'there',
#  'is',
#  'no',
#  'because',
#  'and',
#  'effect',
#  'at',
#  'the',
#  'smallest',
#  'scale',
#  'of',
#  'nature',
#  'the',
#  'quantum',
#  'field',
#  'creates',
#  'the',
#  'physical',
#  'universe',
#  'through',
#  'ripples',
#  'of',
#  'potential',
#  'that',
#  'emerge',
#  'as',
#  'subatomic',
#  'particles',
#  'and',
#  'energy',
#  'waves',
#  'there',
#  'is',
#  'no',
#  'because',
#  'for',
#  'this',
#  'to',
#  'happen',
#  'it',
#  'just',
#  'does',
#  'existence',
#  'has',
#  'no',
#  'because',
#  'an',
#  'obvious',
#  'fact',
#  'once',
#  'you',
#  'think',
#  'about',
#  'it',
#  'the',
#  'new',
#  'age',
#  'phrase',
#  'be',
#  'here',
#  'now',
#  'is',
#  'not',
#  'a',
#  'goal',
#  'you',
#  'can',
#  'not',
#  'help',
#  'but',
#  'be',
#  'here',
#  'now',
#  'since',
#  'that',
#  'is',
#  'the',
#  'definition',
#  'of',
#  'existence',
#  'there',
#  'are',
#  'more',
#  'controversial',
#  'examples',
#  'of',
#  'things',
#  'that',
#  'have',
#  'no',
#  'because',
#  'many',
#  'of',
#  'your',
#  'thoughts',
#  'are',
#  'not',
#  'caused',
#  'by',
#  'the',
#  'thoughts',
#  'that',
#  'preceded',
#  'them',
#  'thoughts',
#  'spring',
#  'up',
#  'unpredictably',
#  'from',
#  'a',
#  'state',
#  'that',
#  'is',
#  'not',
#  'a',
#  'thought',
#  'it',
#  'is',
#  'a',
#  'silent',
#  'domain',
#  'of',
#  'possibilities',
#  'here',
#  'we',
#  'are',
#  'at',
#  'the',
#  'crux',
#  'of',
#  'the',
#  'answer',
#  'if',
#  'you',
#  'do',
#  'not',
#  'know',
#  'how',
#  'thoughts',
#  'arise',
#  'from',
#  'total',
#  'silence',
#  'you',
#  'can',
#  'not',
#  'possibly',
#  'know',
#  'how',
#  'or',
#  'if',
#  'thoughts',
#  'end',
#  'you',
#  'already',
#  'rely',
#  'on',
#  'the',
#  'domain',
#  'of',
#  'silent',
#  'invisible',
#  'possibilities',
#  'all',
#  'the',
#  'time',
#  'you',
#  'fetch',
#  'memories',
#  'from',
#  'this',
#  'domain',
#  'along',
#  'with',
#  'your',
#  'vocabulary',
#  'your',
#  'next',
#  'desire',
#  'and',
#  'your',
#  'identity',
#  'which',
#  'is',
#  'nothing',
#  'more',
#  'than',
#  'a',
#  'constant',
#  'process',
#  'of',
#  'filing',
#  'away',
#  'the',
#  'experiences',
#  'you',
#  'identify',
#  'with',
#  'calling',
#  'them',
#  'me',
#  'the',
#  'nice',
#  'thing',
#  'about',
#  'existence',
#  'is',
#  'that',
#  'it',
#  'can',
#  'be',
#  'relied',
#  'upon',
#  'even',
#  'when',
#  'you',
#  'have',
#  'no',
#  'idea',
#  'where',
#  'it',
#  'came',
#  'from',
#  'to',
#  'be',
#  'or',
#  'not',
#  'to',
#  'be',
#  'is',
#  'the',
#  'wrong',
#  'question',
#  'we',
#  'are',
#  'period',
#  'packaged',
#  'in',
#  'with',
#  'being',
#  'here',
#  'now',
#  'is',
#  'consciousness',
#  'in',
#  'a',
#  'basic',
#  'irrefutable',
#  'way',
#  'existence',
#  'and',
#  'consciousness',
#  'go',
#  'together',
#  'they',
#  'are',
#  'our',
#  'home',
#  'we',
#  'did',
#  'not',
#  'invent',
#  'or',
#  'create',
#  'this',
#  'home',
#  'it',
#  'is',
#  'our',
#  'beginning',
#  'and',
#  'therefore',
#  'our',
#  'end',
#  'wrapped',
#  'into',
#  'one',
#  'except',
#  'that',
#  'the',
#  'words',
#  'beginning',
#  'and',
#  'end',
#  'are',
#  'deceptive',
#  'there',
#  'is',
#  'no',
#  'reason',
#  'to',
#  'assume',
#  'that',
#  'existence',
#  'had',
#  'a',
#  'beginning',
#  'whatever',
#  'you',
#  'imagine',
#  'as',
#  'non',
#  'existence',
#  'is',
#  'a',
#  'concept',
#  'and',
#  'concepts',
#  'being',
#  'mind',
#  'made',
#  'exist',
#  'trying',
#  'to',
#  'nullify',
#  'existence',
#  'becomes',
#  'circular',
#  'we',
#  'are',
#  'all',
#  'at',
#  'home',
#  'here',
#  ...]

# %% [markdown]
# ## Stop Words Removal

# %%
def stopwords_removal(text):
  stopwords = list(STOP_WORDS)
  stopwords_removed = []
  for i in text:
    if i not in stopwords:
      stopwords_removed.append(i)
  return stopwords_removed

# %%
processed_text = stopwords_removal(processed_text)
processed_text
# Out:
# ['main',
#  'reasons',
#  'religion',
#  'spiritual',
#  'tradition',
#  'exists',
#  'reassure',
#  'dying',
#  'fear',
#  'dying',
#  'universal',
#  'hidden',
#  'view',
#  'daily',
#  'life',
#  'religion',
#  'spirituality',
#  'offer',
#  'hope',
#  'fear',
#  'baseless',
#  'happens',
#  'death',
#  'primary',
#  'message',
#  'good',
#  'better',
#  'despite',
#  'advances',
#  'science',
#  'stripped',
#  'away',
#  'reassurances',
#  'life',
#  'death',
#  'people',
#  'modern',
#  'world',
#  'accept',
#  'scientific',
#  'model',
#  'logically',
#  'follows',
#  'physical',
#  'body',
#  'dies',
#  'likelihood',
#  'immaterial',
#  'aspects',
#  'human',
#  'mind',
#  'soul',
#  'memory',
#  'personality',
#  'thoughts',
#  'feelings',
#  'etc',
#  'extinguished',
#  'time',
#  'set',
#  'beliefs',
#  'offer',
#  'proof',
#  'form',
#  'facts',
#  'data',
#  'information',
#  'place',
#  'religious',
#  'certainty',
#  'modern',
#  'people',
#  'face',
#  'death',
#  'fear',
#  'doubt',
#  'dread',
#  'foreboding',
#  'shred',
#  'empirical',
#  'evidence',
#  'happens',
#  'death',
#  'reason',
#  'casually',
#  'believe',
#  'life',
#  'ends',
#  'true',
#  'simply',
#  'absence',
#  'facts',
#  'facts',
#  'end',
#  'science',
#  'follow',
#  'train',
#  'thought',
#  'worldviews',
#  'religiousspiritual',
#  'scientific',
#  'stories',
#  'built',
#  'assumptions',
#  'proven',
#  'ask',
#  'die',
#  'main',
#  'stories',
#  'heavenhell',
#  'vanish',
#  'cloud',
#  'atoms',
#  'energy',
#  'waves',
#  'hollow',
#  'confront',
#  'mystery',
#  'refuses',
#  'reveal',
#  'secrets',
#  'leaves',
#  'begin',
#  'individual',
#  'knowing',
#  'death',
#  'inevitable',
#  'leading',
#  'life',
#  'dedicated',
#  'avoiding',
#  'fact',
#  'fear',
#  'death',
#  'necessary',
#  'worst',
#  'sleep',
#  'night',
#  'going',
#  'sleep',
#  'fearful',
#  'know',
#  'happens',
#  'happens',
#  'good',
#  'working',
#  'attitude',
#  'let',
#  'better',
#  'way',
#  'better',
#  'way',
#  'hinted',
#  'ts',
#  'eliots',
#  'famous',
#  'line',
#  'poetry',
#  'end',
#  'beginning',
#  'religious',
#  'mystical',
#  'statement',
#  'eliot',
#  'deeply',
#  'religious',
#  'words',
#  'mean',
#  'true',
#  'atheists',
#  'believers',
#  'alike',
#  'know',
#  'things',
#  'end',
#  'know',
#  'began',
#  'looks',
#  'like',
#  'simple',
#  'statement',
#  'effect',
#  'observe',
#  'putting',
#  'jar',
#  'upside',
#  'candle',
#  'makes',
#  'flame',
#  'explain',
#  'know',
#  'laws',
#  'chemistry',
#  'reveals',
#  'fire',
#  'needs',
#  'oxygen',
#  'going',
#  'use',
#  'oxygen',
#  'flame',
#  'goes',
#  'deeper',
#  'meaning',
#  'know',
#  'things',
#  'end',
#  'know',
#  'began',
#  'matters',
#  'death',
#  'survival',
#  'consciousness',
#  'observe',
#  'flame',
#  'physical',
#  'body',
#  'die',
#  'mystery',
#  'revolves',
#  'happens',
#  'non',
#  'physical',
#  'things',
#  'previously',
#  'listed',
#  'mind',
#  'soul',
#  'memory',
#  'personality',
#  'thoughts',
#  'feelings',
#  'etc',
#  'experiences',
#  'consciousness',
#  'matter',
#  'unique',
#  'anyones',
#  'life',
#  'consciousness',
#  'brings',
#  'human',
#  'place',
#  'life',
#  'experienced',
#  'consciousness',
#  'know',
#  'consciousness',
#  'begins',
#  'know',
#  'ends',
#  'opposite',
#  'true',
#  'know',
#  'consciousness',
#  'begins',
#  'possibly',
#  'know',
#  'ends',
#  'suddenly',
#  'opening',
#  'true',
#  'revelation',
#  'consciousness',
#  'beginning',
#  'end',
#  'words',
#  'effect',
#  'model',
#  'work',
#  'comes',
#  'consciousness',
#  'explained',
#  'existing',
#  'independent',
#  'obey',
#  'rule',
#  'effect',
#  'outside',
#  'realm',
#  'effect',
#  'absolutely',
#  'universe',
#  'sprang',
#  'state',
#  'preceding',
#  'big',
#  'bang',
#  'offers',
#  'clue',
#  'matter',
#  'energy',
#  'space',
#  'time',
#  'things',
#  'effect',
#  'smallest',
#  'scale',
#  'nature',
#  'quantum',
#  'field',
#  'creates',
#  'physical',
#  'universe',
#  'ripples',
#  'potential',
#  'emerge',
#  'subatomic',
#  'particles',
#  'energy',
#  'waves',
#  'happen',
#  'existence',
#  'obvious',
#  'fact',
#  'think',
#  'new',
#  'age',
#  'phrase',
#  'goal',
#  'help',
#  'definition',
#  'existence',
#  'controversial',
#  'examples',
#  'things',
#  'thoughts',
#  'caused',
#  'thoughts',
#  'preceded',
#  'thoughts',
#  'spring',
#  'unpredictably',
#  'state',
#  'thought',
#  'silent',
#  'domain',
#  'possibilities',
#  'crux',
#  'answer',
#  'know',
#  'thoughts',
#  'arise',
#  'total',
#  'silence',
#  'possibly',
#  'know',
#  'thoughts',
#  'end',
#  'rely',
#  'domain',
#  'silent',
#  'invisible',
#  'possibilities',
#  'time',
#  'fetch',
#  'memories',
#  'domain',
#  'vocabulary',
#  'desire',
#  'identity',
#  'constant',
#  'process',
#  'filing',
#  'away',
#  'experiences',
#  'identify',
#  'calling',
#  'nice',
#  'thing',
#  'existence',
#  'relied',
#  'idea',
#  'came',
#  'wrong',
#  'question',
#  'period',
#  'packaged',
#  'consciousness',
#  'basic',
#  'irrefutable',
#  'way',
#  'existence',
#  'consciousness',
#  'home',
#  'invent',
#  'create',
#  'home',
#  'beginning',
#  'end',
#  'wrapped',
#  'words',
#  'beginning',
#  'end',
#  'deceptive',
#  'reason',
#  'assume',
#  'existence',
#  'beginning',
#  'imagine',
#  'non',
#  'existence',
#  'concept',
#  'concepts',
#  'mind',
#  'exist',
#  'trying',
#  'nullify',
#  'existence',
#  'circular',
#  'home',
#  'conscious',
#  'consciousness',
#  'infinite',
#  'causeless',
#  'invisible',
#  'inconceivable',
#  'origin',
#  'die',
#  'physical',
#  'terms',
#  'leave',
#  'home',
#  'alternative',
#  'non',
#  'existence',
#  'fantasy',
#  'born',
#  'fear',
#  'realize',
#  'making',
#  'existence',
#  'consciousness',
#  'sounds',
#  'alien',
#  'tried',
#  'state',
#  'argument',
#  'simple',
#  'statements',
#  'free',
#  'ponder',
#  'answer',
#  'personal',
#  'look',
#  'life',
#  'gain',
#  'like',
#  'stable',
#  'set',
#  'conclusions',
#  'explore',
#  'like',
#  'home',
#  'realize',
#  'leave',
#  'home',
#  'new',
#  'worldview',
#  'emerges',
#  'look',
#  'deep']

# %% [markdown]
# ## Text Preprocessing Final Function

# %%
def preprocess(text):
  text = expand_contractions(text)
  text = punctuations_removal(text)
  text = extraspace_removal(text)
  text = tokenizing(text)
  text = lowercasing(text)
  text = stopwords_removal(text)
  return text

# %% [markdown]
# # Calculating Word Frequency Distribution

# %% [markdown]
# ## Calculating Word Frequency

# %%
def calc_words_freq(text):
  words_frequency = dict()
  for i in text:
    if i not in words_frequency:
      words_frequency[i] = 1
    else:
      words_frequency[i] += 1
  return words_frequency

# %%
words_frequency = calc_words_freq(processed_text)
words_frequency
# Out:
# {'main': 2,
#  'reasons': 1,
#  'religion': 2,
#  'spiritual': 1,
#  'tradition': 1,
#  'exists': 1,
#  'reassure': 1,
#  'dying': 2,
#  'fear': 5,
#  'universal': 1,
#  'hidden': 1,
#  'view': 1,
#  'daily': 1,
#  'life': 7,
#  'spirituality': 1,
#  'offer': 2,
#  'hope': 1,
#  'baseless': 1,
#  'happens': 5,
#  'death': 7,
#  'primary': 1,
#  'message': 1,
#  'good': 2,
#  'better': 3,
#  'despite': 1,
#  'advances': 1,
#  'science': 2,
#  'stripped': 1,
#  'away': 2,
#  'reassurances': 1,
#  'people': 2,
#  'modern': 2,
#  'world': 1,
#  'accept': 1,
#  'scientific': 2,
#  'model': 2,
#  'logically': 1,
#  'follows': 1,
#  'physical': 5,
#  'body': 2,
#  'dies': 1,
#  'likelihood': 1,
#  'immaterial': 1,
#  'aspects': 1,
#  'human': 2,
#  'mind': 3,
#  'soul': 2,
#  'memory': 2,
#  'personality': 2,
#  'thoughts': 7,
#  'feelings': 2,
#  'etc': 2,
#  'extinguished': 1,
#  'time': 3,
#  'set': 2,
#  'beliefs': 1,
#  'proof': 1,
#  'form': 1,
#  'facts': 3,
#  'data': 1,
#  'information': 1,
#  'place': 2,
#  'religious': 3,
#  'certainty': 1,
#  'face': 1,
#  'doubt': 1,
#  'dread': 1,
#  'foreboding': 1,
#  'shred': 1,
#  'empirical': 1,
#  'evidence': 1,
#  'reason': 2,
#  'casually': 1,
#  'believe': 1,
#  'ends': 3,
#  'true': 4,
#  'simply': 1,
#  'absence': 1,
#  'end': 8,
#  'follow': 1,
#  'train': 1,
#  'thought': 2,
#  'worldviews': 1,
#  'religiousspiritual': 1,
#  'stories': 2,
#  'built': 1,
#  'assumptions': 1,
#  'proven': 1,
#  'ask': 1,
#  'die': 3,
#  'heavenhell': 1,
#  'vanish': 1,
#  'cloud': 1,
#  'atoms': 1,
#  'energy': 3,
#  'waves': 2,
#  'hollow': 1,
#  'confront': 1,
#  'mystery': 2,
#  'refuses': 1,
#  'reveal': 1,
#  'secrets': 1,
#  'leaves': 1,
#  'begin': 1,
#  'individual': 1,
#  'knowing': 1,
#  'inevitable': 1,
#  'leading': 1,
#  'dedicated': 1,
#  'avoiding': 1,
#  'fact': 2,
#  'necessary': 1,
#  'worst': 1,
#  'sleep': 2,
#  'night': 1,
#  'going': 2,
#  'fearful': 1,
#  'know': 12,
#  'working': 1,
#  'attitude': 1,
#  'let': 1,
#  'way': 3,
#  'hinted': 1,
#  'ts': 1,
#  'eliots': 1,
#  'famous': 1,
#  'line': 1,
#  'poetry': 1,
#  'beginning': 5,
#  'mystical': 1,
#  'statement': 2,
#  'eliot': 1,
#  'deeply': 1,
#  'words': 3,
#  'mean': 1,
#  'atheists': 1,
#  'believers': 1,
#  'alike': 1,
#  'things': 5,
#  'began': 2,
#  'looks': 1,
#  'like': 3,
#  'simple': 2,
#  'effect': 5,
#  'observe': 2,
#  'putting': 1,
#  'jar': 1,
#  'upside': 1,
#  'candle': 1,
#  'makes': 1,
#  'flame': 3,
#  'explain': 1,
#  'laws': 1,
#  'chemistry': 1,
#  'reveals': 1,
#  'fire': 1,
#  'needs': 1,
#  'oxygen': 2,
#  'use': 1,
#  'goes': 1,
#  'deeper': 1,
#  'meaning': 1,
#  'matters': 1,
#  'survival': 1,
#  'consciousness': 12,
#  'revolves': 1,
#  'non': 3,
#  'previously': 1,
#  'listed': 1,
#  'experiences': 2,
#  'matter': 2,
#  'unique': 1,
#  'anyones': 1,
#  'brings': 1,
#  'experienced': 1,
#  'begins': 2,
#  'opposite': 1,
#  'possibly': 2,
#  'suddenly': 1,
#  'opening': 1,
#  'revelation': 1,
#  'work': 1,
#  'comes': 1,
#  'explained': 1,
#  'existing': 1,
#  'independent': 1,
#  'obey': 1,
#  'rule': 1,
#  'outside': 1,
#  'realm': 1,
#  'absolutely': 1,
#  'universe': 2,
#  'sprang': 1,
#  'state': 3,
#  'preceding': 1,
#  'big': 1,
#  'bang': 1,
#  'offers': 1,
#  'clue': 1,
#  'space': 1,
#  'smallest': 1,
#  'scale': 1,
#  'nature': 1,
#  'quantum': 1,
#  'field': 1,
#  'creates': 1,
#  'ripples': 1,
#  'potential': 1,
#  'emerge': 1,
#  'subatomic': 1,
#  'particles': 1,
#  'happen': 1,
#  'existence': 9,
#  'obvious': 1,
#  'think': 1,
#  'new': 2,
#  'age': 1,
#  'phrase': 1,
#  'goal': 1,
#  'help': 1,
#  'definition': 1,
#  'controversial': 1,
#  'examples': 1,
#  'caused': 1,
#  'preceded': 1,
#  'spring': 1,
#  'unpredictably': 1,
#  'silent': 2,
#  'domain': 3,
#  'possibilities': 2,
#  'crux': 1,
#  'answer': 2,
#  'arise': 1,
#  'total': 1,
#  'silence': 1,
#  'rely': 1,
#  'invisible': 2,
#  'fetch': 1,
#  'memories': 1,
#  'vocabulary': 1,
#  'desire': 1,
#  'identity': 1,
#  'constant': 1,
#  'process': 1,
#  'filing': 1,
#  'identify': 1,
#  'calling': 1,
#  'nice': 1,
#  'thing': 1,
#  'relied': 1,
#  'idea': 1,
#  'came': 1,
#  'wrong': 1,
#  'question': 1,
#  'period': 1,
#  'packaged': 1,
#  'basic': 1,
#  'irrefutable': 1,
#  'home': 6,
#  'invent': 1,
#  'create': 1,
#  'wrapped': 1,
#  'deceptive': 1,
#  'assume': 1,
#  'imagine': 1,
#  'concept': 1,
#  'concepts': 1,
#  'exist': 1,
#  'trying': 1,
#  'nullify': 1,
#  'circular': 1,
#  'conscious': 1,
#  'infinite': 1,
#  'causeless': 1,
#  'inconceivable': 1,
#  'origin': 1,
#  'terms': 1,
#  'leave': 2,
#  'alternative': 1,
#  'fantasy': 1,
#  'born': 1,
#  'realize': 2,
#  'making': 1,
#  'sounds': 1,
#  'alien': 1,
#  'tried': 1,
#  'argument': 1,
#  'statements': 1,
#  'free': 1,
#  'ponder': 1,
#  'personal': 1,
#  'look': 2,
#  'gain': 1,
#  'stable': 1,
#  'conclusions': 1,
#  'explore': 1,
#  'worldview': 1,
#  'emerges': 1,
#  'deep': 1}

# %% [markdown]
# ## Word Frequency Distribution

# %%
def calc_words_freq_dist(text):
  words_frequency = calc_words_freq(text)
  maximum_frequency = max(words_frequency.values())
  for i in words_frequency:
    words_frequency[i] = words_frequency[i] / maximum_frequency
  return words_frequency

# %%
words_frequency = calc_words_freq_dist(processed_text)
words_frequency
# Out:
# {'main': 0.16666666666666666,
#  'reasons': 0.08333333333333333,
#  'religion': 0.16666666666666666,
#  'spiritual': 0.08333333333333333,
#  'tradition': 0.08333333333333333,
#  'exists': 0.08333333333333333,
#  'reassure': 0.08333333333333333,
#  'dying': 0.16666666666666666,
#  'fear': 0.4166666666666667,
#  'universal': 0.08333333333333333,
#  'hidden': 0.08333333333333333,
#  'view': 0.08333333333333333,
#  'daily': 0.08333333333333333,
#  'life': 0.5833333333333334,
#  'spirituality': 0.08333333333333333,
#  'offer': 0.16666666666666666,
#  'hope': 0.08333333333333333,
#  'baseless': 0.08333333333333333,
#  'happens': 0.4166666666666667,
#  'death': 0.5833333333333334,
#  'primary': 0.08333333333333333,
#  'message': 0.08333333333333333,
#  'good': 0.16666666666666666,
#  'better': 0.25,
#  'despite': 0.08333333333333333,
#  'advances': 0.08333333333333333,
#  'science': 0.16666666666666666,
#  'stripped': 0.08333333333333333,
#  'away': 0.16666666666666666,
#  'reassurances': 0.08333333333333333,
#  'people': 0.16666666666666666,
#  'modern': 0.16666666666666666,
#  'world': 0.08333333333333333,
#  'accept': 0.08333333333333333,
#  'scientific': 0.16666666666666666,
#  'model': 0.16666666666666666,
#  'logically': 0.08333333333333333,
#  'follows': 0.08333333333333333,
#  'physical': 0.4166666666666667,
#  'body': 0.16666666666666666,
#  'dies': 0.08333333333333333,
#  'likelihood': 0.08333333333333333,
#  'immaterial': 0.08333333333333333,
#  'aspects': 0.08333333333333333,
#  'human': 0.16666666666666666,
#  'mind': 0.25,
#  'soul': 0.16666666666666666,
#  'memory': 0.16666666666666666,
#  'personality': 0.16666666666666666,
#  'thoughts': 0.5833333333333334,
#  'feelings': 0.16666666666666666,
#  'etc': 0.16666666666666666,
#  'extinguished': 0.08333333333333333,
#  'time': 0.25,
#  'set': 0.16666666666666666,
#  'beliefs': 0.08333333333333333,
#  'proof': 0.08333333333333333,
#  'form': 0.08333333333333333,
#  'facts': 0.25,
#  'data': 0.08333333333333333,
#  'information': 0.08333333333333333,
#  'place': 0.16666666666666666,
#  'religious': 0.25,
#  'certainty': 0.08333333333333333,
#  'face': 0.08333333333333333,
#  'doubt': 0.08333333333333333,
#  'dread': 0.08333333333333333,
#  'foreboding': 0.08333333333333333,
#  'shred': 0.08333333333333333,
#  'empirical': 0.08333333333333333,
#  'evidence': 0.08333333333333333,
#  'reason': 0.16666666666666666,
#  'casually': 0.08333333333333333,
#  'believe': 0.08333333333333333,
#  'ends': 0.25,
#  'true': 0.3333333333333333,
#  'simply': 0.08333333333333333,
#  'absence': 0.08333333333333333,
#  'end': 0.6666666666666666,
#  'follow': 0.08333333333333333,
#  'train': 0.08333333333333333,
#  'thought': 0.16666666666666666,
#  'worldviews': 0.08333333333333333,
#  'religiousspiritual': 0.08333333333333333,
#  'stories': 0.16666666666666666,
#  'built': 0.08333333333333333,
#  'assumptions': 0.08333333333333333,
#  'proven': 0.08333333333333333,
#  'ask': 0.08333333333333333,
#  'die': 0.25,
#  'heavenhell': 0.08333333333333333,
#  'vanish': 0.08333333333333333,
#  'cloud': 0.08333333333333333,
#  'atoms': 0.08333333333333333,
#  'energy': 0.25,
#  'waves': 0.16666666666666666,
#  'hollow': 0.08333333333333333,
#  'confront': 0.08333333333333333,
#  'mystery': 0.16666666666666666,
#  'refuses': 0.08333333333333333,
#  'reveal': 0.08333333333333333,
#  'secrets': 0.08333333333333333,
#  'leaves': 0.08333333333333333,
#  'begin': 0.08333333333333333,
#  'individual': 0.08333333333333333,
#  'knowing': 0.08333333333333333,
#  'inevitable': 0.08333333333333333,
#  'leading': 0.08333333333333333,
#  'dedicated': 0.08333333333333333,
#  'avoiding': 0.08333333333333333,
#  'fact': 0.16666666666666666,
#  'necessary': 0.08333333333333333,
#  'worst': 0.08333333333333333,
#  'sleep': 0.16666666666666666,
#  'night': 0.08333333333333333,
#  'going': 0.16666666666666666,
#  'fearful': 0.08333333333333333,
#  'know': 1.0,
#  'working': 0.08333333333333333,
#  'attitude': 0.08333333333333333,
#  'let': 0.08333333333333333,
#  'way': 0.25,
#  'hinted': 0.08333333333333333,
#  'ts': 0.08333333333333333,
#  'eliots': 0.08333333333333333,
#  'famous': 0.08333333333333333,
#  'line': 0.08333333333333333,
#  'poetry': 0.08333333333333333,
#  'beginning': 0.4166666666666667,
#  'mystical': 0.08333333333333333,
#  'statement': 0.16666666666666666,
#  'eliot': 0.08333333333333333,
#  'deeply': 0.08333333333333333,
#  'words': 0.25,
#  'mean': 0.08333333333333333,
#  'atheists': 0.08333333333333333,
#  'believers': 0.08333333333333333,
#  'alike': 0.08333333333333333,
#  'things': 0.4166666666666667,
#  'began': 0.16666666666666666,
#  'looks': 0.08333333333333333,
#  'like': 0.25,
#  'simple': 0.16666666666666666,
#  'effect': 0.4166666666666667,
#  'observe': 0.16666666666666666,
#  'putting': 0.08333333333333333,
#  'jar': 0.08333333333333333,
#  'upside': 0.08333333333333333,
#  'candle': 0.08333333333333333,
#  'makes': 0.08333333333333333,
#  'flame': 0.25,
#  'explain': 0.08333333333333333,
#  'laws': 0.08333333333333333,
#  'chemistry': 0.08333333333333333,
#  'reveals': 0.08333333333333333,
#  'fire': 0.08333333333333333,
#  'needs': 0.08333333333333333,
#  'oxygen': 0.16666666666666666,
#  'use': 0.08333333333333333,
#  'goes': 0.08333333333333333,
#  'deeper': 0.08333333333333333,
#  'meaning': 0.08333333333333333,
#  'matters': 0.08333333333333333,
#  'survival': 0.08333333333333333,
#  'consciousness': 1.0,
#  'revolves': 0.08333333333333333,
#  'non': 0.25,
#  'previously': 0.08333333333333333,
#  'listed': 0.08333333333333333,
#  'experiences': 0.16666666666666666,
#  'matter': 0.16666666666666666,
#  'unique': 0.08333333333333333,
#  'anyones': 0.08333333333333333,
#  'brings': 0.08333333333333333,
#  'experienced': 0.08333333333333333,
#  'begins': 0.16666666666666666,
#  'opposite': 0.08333333333333333,
#  'possibly': 0.16666666666666666,
#  'suddenly': 0.08333333333333333,
#  'opening': 0.08333333333333333,
#  'revelation': 0.08333333333333333,
#  'work': 0.08333333333333333,
#  'comes': 0.08333333333333333,
#  'explained': 0.08333333333333333,
#  'existing': 0.08333333333333333,
#  'independent': 0.08333333333333333,
#  'obey': 0.08333333333333333,
#  'rule': 0.08333333333333333,
#  'outside': 0.08333333333333333,
#  'realm': 0.08333333333333333,
#  'absolutely': 0.08333333333333333,
#  'universe': 0.16666666666666666,
#  'sprang': 0.08333333333333333,
#  'state': 0.25,
#  'preceding': 0.08333333333333333,
#  'big': 0.08333333333333333,
#  'bang': 0.08333333333333333,
#  'offers': 0.08333333333333333,
#  'clue': 0.08333333333333333,
#  'space': 0.08333333333333333,
#  'smallest': 0.08333333333333333,
#  'scale': 0.08333333333333333,
#  'nature': 0.08333333333333333,
#  'quantum': 0.08333333333333333,
#  'field': 0.08333333333333333,
#  'creates': 0.08333333333333333,
#  'ripples': 0.08333333333333333,
#  'potential': 0.08333333333333333,
#  'emerge': 0.08333333333333333,
#  'subatomic': 0.08333333333333333,
#  'particles': 0.08333333333333333,
#  'happen': 0.08333333333333333,
#  'existence': 0.75,
#  'obvious': 0.08333333333333333,
#  'think': 0.08333333333333333,
#  'new': 0.16666666666666666,
#  'age': 0.08333333333333333,
#  'phrase': 0.08333333333333333,
#  'goal': 0.08333333333333333,
#  'help': 0.08333333333333333,
#  'definition': 0.08333333333333333,
#  'controversial': 0.08333333333333333,
#  'examples': 0.08333333333333333,
#  'caused': 0.08333333333333333,
#  'preceded': 0.08333333333333333,
#  'spring': 0.08333333333333333,
#  'unpredictably': 0.08333333333333333,
#  'silent': 0.16666666666666666,
#  'domain': 0.25,
#  'possibilities': 0.16666666666666666,
#  'crux': 0.08333333333333333,
#  'answer': 0.16666666666666666,
#  'arise': 0.08333333333333333,
#  'total': 0.08333333333333333,
#  'silence': 0.08333333333333333,
#  'rely': 0.08333333333333333,
#  'invisible': 0.16666666666666666,
#  'fetch': 0.08333333333333333,
#  'memories': 0.08333333333333333,
#  'vocabulary': 0.08333333333333333,
#  'desire': 0.08333333333333333,
#  'identity': 0.08333333333333333,
#  'constant': 0.08333333333333333,
#  'process': 0.08333333333333333,
#  'filing': 0.08333333333333333,
#  'identify': 0.08333333333333333,
#  'calling': 0.08333333333333333,
#  'nice': 0.08333333333333333,
#  'thing': 0.08333333333333333,
#  'relied': 0.08333333333333333,
#  'idea': 0.08333333333333333,
#  'came': 0.08333333333333333,
#  'wrong': 0.08333333333333333,
#  'question': 0.08333333333333333,
#  'period': 0.08333333333333333,
#  'packaged': 0.08333333333333333,
#  'basic': 0.08333333333333333,
#  'irrefutable': 0.08333333333333333,
#  'home': 0.5,
#  'invent': 0.08333333333333333,
#  'create': 0.08333333333333333,
#  'wrapped': 0.08333333333333333,
#  'deceptive': 0.08333333333333333,
#  'assume': 0.08333333333333333,
#  'imagine': 0.08333333333333333,
#  'concept': 0.08333333333333333,
#  'concepts': 0.08333333333333333,
#  'exist': 0.08333333333333333,
#  'trying': 0.08333333333333333,
#  'nullify': 0.08333333333333333,
#  'circular': 0.08333333333333333,
#  'conscious': 0.08333333333333333,
#  'infinite': 0.08333333333333333,
#  'causeless': 0.08333333333333333,
#  'inconceivable': 0.08333333333333333,
#  'origin': 0.08333333333333333,
#  'terms': 0.08333333333333333,
#  'leave': 0.16666666666666666,
#  'alternative': 0.08333333333333333,
#  'fantasy': 0.08333333333333333,
#  'born': 0.08333333333333333,
#  'realize': 0.16666666666666666,
#  'making': 0.08333333333333333,
#  'sounds': 0.08333333333333333,
#  'alien': 0.08333333333333333,
#  'tried': 0.08333333333333333,
#  'argument': 0.08333333333333333,
#  'statements': 0.08333333333333333,
#  'free': 0.08333333333333333,
#  'ponder': 0.08333333333333333,
#  'personal': 0.08333333333333333,
#  'look': 0.16666666666666666,
#  'gain': 0.08333333333333333,
#  'stable': 0.08333333333333333,
#  'conclusions': 0.08333333333333333,
#  'explore': 0.08333333333333333,
#  'worldview': 0.08333333333333333,
#  'emerges': 0.08333333333333333,
#  'deep': 0.08333333333333333}

# %% [markdown]
# ## Calculating Sentence Score

# %% [markdown]
# ### Tokenizing Sentence

# %%
def sentence_tokenizing(text):
  sentences = nlp(expand_contractions(text))
  sentences_list = []
  for i in sentences.sents:
    sentences_list.append(i)
  return sentences_list

# %%
sentences_list = sentence_tokenizing(text)
sentences_list
# Out:
# [One of the main reasons that any religion or spiritual tradition exists is to reassure us about dying.,
#  Fear of dying is universal but hidden from view in daily life.,
#  Religion and spirituality offer hope that this fear is baseless.,
#  Something happens after death — this is the primary message — and this something is good, or at least it is better than nothing.,
#  Despite all of its advances, science has stripped away any reassurances about life after death, and most people in the modern world accept the scientific model.,
#  In doing so it logically follows that when the physical body dies, in all likelihood the immaterial aspects of being human — mind soul, memory personality, thoughts, feelings, etc. — are extinguished at the same time.,
#  What this set of beliefs does not offer is proof, in the form of facts, data, information, and so on.,
#  In place of religious certainty, modern people face death, not only with fear, doubt, dread, and foreboding but without a shred of empirical evidence about what happens after death.,
#  The reason that we casually believe that life ends with nothing is not because that is true.,
#  Nothing is simply the absence of facts.,
#  When facts end, science has nothing to say.,
#  If you follow this train of thought, both worldviews, the religious/spiritual and the scientific, amount to stories built around assumptions that cannot be proven.,
#  When you ask, “Where do we go after we die?”,
#  the two main stories — we go to heaven/hell or we vanish into a cloud of atoms and energy waves — are hollow.,
#  They confront a mystery that refuses to reveal its secrets.,
#  Where this leaves us is really where we begin, with the individual knowing that death is inevitable but leading a life dedicated to avoiding that fact.,
#  Fear of death is not necessary.,
#  At worst, we go to sleep just as we do every night, and going to sleep is not fearful.,
#  “I will know what happens when it happens” is a good working attitude, but let us see if there is a better way.,
#  A better way is hinted at in T.S. Eliot’s famous line of poetry, “In my end is my beginning.”,
#  This is not a religious or mystical statement, although Eliot was deeply religious.,
#  What these words mean is true for everyone, atheists and believers alike.,
#  You cannot know how things end until you know how they began.,
#  This looks like a simple statement of because and effect.,
#  If you observe that putting a jar upside down over a candle makes the flame go out, you cannot explain this until you know the laws of chemistry, which reveals that fire needs oxygen to keep going.,
#  Use up the oxygen, and the flame goes out.,
#  But there is a deeper meaning to “You cannot know how things end until you know how they began.”,
#  What really matters about death is the survival of consciousness.,
#  We observe the flame (the physical body) go out (die), but the mystery revolves around what happens to the non-physical part of ourselves.,
#  The things previously listed — mind soul, memory, personality, thoughts, feelings, etc. — are all experiences in consciousness.,
#  No matter how unique anyone’s life is, consciousness brings every human being together in the same place.,
#  Life is experienced in consciousness.,
#  Therefore, if we know how consciousness begins, we know how it ends.,
#  The opposite is also true.,
#  If we do not know how consciousness begins, we cannot possibly know how (or if) it ends.,
#  Suddenly there is an opening for a true revelation.,
#  If consciousness has no beginning, then it has no end.,
#  In other words, the because-and-effect model does not work when it comes to consciousness.,
#  It can only be explained as existing on its own, independent of everything that does obey the rule of because and effect.,
#  Can anything really be outside the realm of because and effect?,
#  Absolutely.,
#  The universe sprang from a state preceding the Big Bang that offers no clue about matter, energy, space, or time.,
#  Without those things, there is no because and effect.,
#  At the smallest scale of nature, the quantum field creates the physical universe through ripples of potential that emerge as subatomic particles and energy waves.,
#  There is no because for this to happen; it just does.,
#  Existence has no because, an obvious fact once you think about it.,
#  The New Age phrase, “Be here now,” is not a goal.,
#  You cannot help but be here now, since that is the definition of existence.,
#  There are more controversial examples of things that have no because.,
#  Many of your thoughts are not caused by the thoughts that preceded them.,
#  Thoughts spring up unpredictably from a state that is not a thought.,
#  It is a silent domain of possibilities.,
#  Here we are at the crux of the answer.,
#  If you do not know how thoughts arise from total silence, you cannot possibly know how or if thoughts end.,
#  You already rely on the domain of silent, invisible possibilities all the time.,
#  You fetch memories from this domain, along with your vocabulary, your next desire, and your identity, which is nothing more than a constant process of filing away the experiences you identify with, calling them “me.”,
#  The nice thing about existence is that it can be relied upon even when you have no idea where it came from.,
#  “To be or not to be” is the wrong question.,
#  We are, period.,
#  Packaged in with being here now is consciousness.,
#  In a basic, irrefutable way, existence and consciousness go together.,
#  They are our home.,
#  We did not invent or create this home.,
#  It is our beginning and therefore our end, wrapped into one.,
#  Except that the words “beginning” and “end” are deceptive.,
#  There is no reason to assume that existence had a beginning.,
#  Whatever you imagine as non-existence is a concept, and concepts, being mind-made, exist.,
#  Trying to nullify existence becomes circular.,
#  We are all at home here and now.,
#  We could not be conscious without consciousness, the infinite, causeless, invisible, inconceivable origin of everything.,
#  Where do we go after we die?,
#  Nowhere in physical terms.,
#  We never leave home because there is no alternative.,
#  Non-existence is a fantasy born of fear.,
#  I realize that making existence the same as consciousness sounds alien.,
#  I have tried to state the argument in simple statements that anyone is free to ponder.,
#  The answer has to be personal.,
#  You have to look at what life is, here and now, to gain anything like a stable set of conclusions.,
#  Explore what it is like to be at home, and you will realize that you can never leave home.,
#  A new worldview emerges if you look deep enough.]

# %% [markdown]
# ### Calculating Sentences Score

# %%
def calc_sentence_score(text, words_frequency):
  sentences_list = sentence_tokenizing(text)
  sentences_scores = dict()
  for sent in sentences_list:
    for word in sent:
      if word.text.lower() in words_frequency:
        if sent not in sentences_scores:
          sentences_scores[sent] = words_frequency[word.text.lower()]
        else:
          sentences_scores[sent] += words_frequency[word.text.lower()]
  return sentences_scores

# %%
sentences_scores = calc_sentence_score(text, words_frequency)
sentences_scores
# Out:
# {One of the main reasons that any religion or spiritual tradition exists is to reassure us about dying.: 0.9166666666666666,
#  Fear of dying is universal but hidden from view in daily life.: 1.5000000000000002,
#  Religion and spirituality offer hope that this fear is baseless.: 1.0,
#  Something happens after death — this is the primary message — and this something is good, or at least it is better than nothing.: 1.5833333333333333,
#  Despite all of its advances, science has stripped away any reassurances about life after death, and most people in the modern world accept the scientific model.: 2.6666666666666665,
#  In doing so it logically follows that when the physical body dies, in all likelihood the immaterial aspects of being human — mind soul, memory personality, thoughts, feelings, etc. — are extinguished at the same time.: 3.25,
#  What this set of beliefs does not offer is proof, in the form of facts, data, information, and so on.: 1.0,
#  In place of religious certainty, modern people face death, not only with fear, doubt, dread, and foreboding but without a shred of empirical evidence about what happens after death.: 3.4166666666666674,
#  The reason that we casually believe that life ends with nothing is not because that is true.: 1.5,
#  Nothing is simply the absence of facts.: 0.41666666666666663,
#  When facts end, science has nothing to say.: 1.0833333333333333,
#  If you follow this train of thought, both worldviews, the religious/spiritual and the scientific, amount to stories built around assumptions that cannot be proven.: 1.333333333333333,
#  When you ask, “Where do we go after we die?”: 0.3333333333333333,
#  the two main stories — we go to heaven/hell or we vanish into a cloud of atoms and energy waves — are hollow.: 1.0833333333333333,
#  They confront a mystery that refuses to reveal its secrets.: 0.49999999999999994,
#  Where this leaves us is really where we begin, with the individual knowing that death is inevitable but leading a life dedicated to avoiding that fact.: 1.9999999999999998,
#  Fear of death is not necessary.: 1.0833333333333333,
#  At worst, we go to sleep just as we do every night, and going to sleep is not fearful.: 0.75,
#  “I will know what happens when it happens” is a good working attitude, but let us see if there is a better way.: 2.7500000000000004,
#  A better way is hinted at in T.S. Eliot’s famous line of poetry, “In my end is my beginning.”: 2.0,
#  This is not a religious or mystical statement, although Eliot was deeply religious.: 0.9166666666666667,
#  What these words mean is true for everyone, atheists and believers alike.: 0.9166666666666667,
#  You cannot know how things end until you know how they began.: 3.25,
#  This looks like a simple statement of because and effect.: 1.0833333333333333,
#  If you observe that putting a jar upside down over a candle makes the flame go out, you cannot explain this until you know the laws of chemistry, which reveals that fire needs oxygen to keep going.: 2.6666666666666665,
#  Use up the oxygen, and the flame goes out.: 0.5833333333333334,
#  But there is a deeper meaning to “You cannot know how things end until you know how they began.”: 3.4166666666666665,
#  What really matters about death is the survival of consciousness.: 1.75,
#  We observe the flame (the physical body) go out (die), but the mystery revolves around what happens to the non-physical part of ourselves.: 2.5833333333333335,
#  The things previously listed — mind soul, memory, personality, thoughts, feelings, etc. — are all experiences in consciousness.: 3.4166666666666665,
#  No matter how unique anyone’s life is, consciousness brings every human being together in the same place.: 2.25,
#  Life is experienced in consciousness.: 1.6666666666666667,
#  Therefore, if we know how consciousness begins, we know how it ends.: 3.4166666666666665,
#  The opposite is also true.: 0.41666666666666663,
#  If we do not know how consciousness begins, we cannot possibly know how (or if) it ends.: 3.583333333333333,
#  Suddenly there is an opening for a true revelation.: 0.5833333333333334,
#  If consciousness has no beginning, then it has no end.: 2.0833333333333335,
#  In other words, the because-and-effect model does not work when it comes to consciousness.: 2.0,
#  It can only be explained as existing on its own, independent of everything that does obey the rule of because and effect.: 0.8333333333333333,
#  Can anything really be outside the realm of because and effect?: 0.5833333333333334,
#  Absolutely.: 0.08333333333333333,
#  The universe sprang from a state preceding the Big Bang that offers no clue about matter, energy, space, or time.: 1.6666666666666667,
#  Without those things, there is no because and effect.: 0.8333333333333334,
#  At the smallest scale of nature, the quantum field creates the physical universe through ripples of potential that emerge as subatomic particles and energy waves.: 1.9166666666666663,
#  There is no because for this to happen; it just does.: 0.08333333333333333,
#  Existence has no because, an obvious fact once you think about it.: 1.0833333333333333,
#  The New Age phrase, “Be here now,” is not a goal.: 0.41666666666666663,
#  You cannot help but be here now, since that is the definition of existence.: 0.9166666666666666,
#  There are more controversial examples of things that have no because.: 0.5833333333333334,
#  Many of your thoughts are not caused by the thoughts that preceded them.: 1.3333333333333333,
#  Thoughts spring up unpredictably from a state that is not a thought.: 1.1666666666666667,
#  It is a silent domain of possibilities.: 0.5833333333333333,
#  Here we are at the crux of the answer.: 0.25,
#  If you do not know how thoughts arise from total silence, you cannot possibly know how or if thoughts end.: 4.25,
#  You already rely on the domain of silent, invisible possibilities all the time.: 1.0833333333333333,
#  You fetch memories from this domain, along with your vocabulary, your next desire, and your identity, which is nothing more than a constant process of filing away the experiences you identify with, calling them “me.”: 1.4166666666666667,
#  The nice thing about existence is that it can be relied upon even when you have no idea where it came from.: 1.1666666666666665,
#  “To be or not to be” is the wrong question.: 0.16666666666666666,
#  We are, period.: 0.08333333333333333,
#  Packaged in with being here now is consciousness.: 1.0833333333333333,
#  In a basic, irrefutable way, existence and consciousness go together.: 2.1666666666666665,
#  They are our home.: 0.5,
#  We did not invent or create this home.: 0.6666666666666666,
#  It is our beginning and therefore our end, wrapped into one.: 1.1666666666666665,
#  Except that the words “beginning” and “end” are deceptive.: 1.4166666666666667,
#  There is no reason to assume that existence had a beginning.: 1.4166666666666667,
#  Whatever you imagine as non-existence is a concept, and concepts, being mind-made, exist.: 1.583333333333333,
#  Trying to nullify existence becomes circular.: 1.0,
#  We are all at home here and now.: 0.5,
#  We could not be conscious without consciousness, the infinite, causeless, invisible, inconceivable origin of everything.: 1.583333333333333,
#  Where do we go after we die?: 0.25,
#  Nowhere in physical terms.: 0.5,
#  We never leave home because there is no alternative.: 0.75,
#  Non-existence is a fantasy born of fear.: 1.5833333333333333,
#  I realize that making existence the same as consciousness sounds alien.: 2.166666666666667,
#  I have tried to state the argument in simple statements that anyone is free to ponder.: 0.8333333333333334,
#  The answer has to be personal.: 0.25,
#  You have to look at what life is, here and now, to gain anything like a stable set of conclusions.: 1.4166666666666667,
#  Explore what it is like to be at home, and you will realize that you can never leave home.: 1.6666666666666665,
#  A new worldview emerges if you look deep enough.: 0.5833333333333334}

# %% [markdown]
# # Getting the Summary

# %%
def calc_ratio(summary, text, sentences, sentences_scores):
  ratio_w = len(summary) / len(text) * 100
  ratio_s = len(sentences) / len(sentences_scores) * 100
  print("Ratio by Words: ", ratio_w)
  print("Ratio by Sentences: ", ratio_s)

# %%
def summarize_raw(text, sentence_scores, threshold):
  total_sentences = len(sentence_scores)
  threshold = int(total_sentences * threshold)
  
  sorted_sentences = sorted(sentence_scores.items(), key=lambda item: item[1], reverse=True)[:threshold]
  sentences = [key.text for key, value in sorted_sentences]
  summary = " ".join(sentences)
  calc_ratio(summary, text, sentences, sentences_scores)
  return summary

# %%
result = []
result.append(summarize_raw(text, sentences_scores, 0.15))
# Out:
# Ratio by Words:  24.497802887633398
# Ratio by Sentences:  15.0

# %%
print("\033[91mBEFORE: ")
print("\033[97mLength:", len(text))
print(text)
# Out:
# BEFORE:
# Length: 6372
#
# One of the main reasons that any religion or spiritual tradition exists is to reassure us about dying. Fear of dying is universal but hidden from view in daily life. Religion and spirituality offer hope that this fear is baseless. Something happens after death — this is the primary message — and this something is good, or at least it is better than nothing.
#
# Despite all of its advances, science has stripped away any reassurances about life after death, and most people in the modern world accept the scientific model. In doing so it logically follows that when the physical body dies, in all likelihood the immaterial aspects of being human — mind soul, memory personality, thoughts, feelings, etc. — are extinguished at the same time.
#
# What this set of beliefs doesn’t offer is proof, in the form of facts, data, information, and so on. In place of religious certainty, modern people face death, not only with fear, doubt, dread, and foreboding but without a shred of empirical evidence about what happens after death. The reason that we casually believe that life ends with nothing isn’t because that’s true. Nothing is simply the absence of facts. When facts end, science has nothing to say.
#
# If you follow this train of thought, both worldviews, the religious/spiritual and the scientific, amount to stories built around assumptions that can’t be proven. When you ask, “Where do we go after we die?” the two main stories — we go to heaven/hell or we vanish into a cloud of atoms and energy waves — are hollow. They confront a mystery that refuses to reveal its secrets.
#
# Where this leaves us is really where we begin, with the individual knowing that death is inevitable but leading a life dedicated to avoiding that fact. Fear of death isn’t necessary. At worst, we go to sleep just as we do every night, and going to sleep isn’t fearful. “I’ll know what happens when it happens” is a good working attitude, but let’s see if there is a better way.
#
# A better way is hinted at in T.S. Eliot’s famous line of poetry, “In my end is my beginning.” This isn’t a religious or mystical statement, although Eliot was deeply religious. What these words mean is true for everyone, atheists and believers alike.
#
# You can’t know how things end until you know how they began.
#
# This looks like a simple statement of cause and effect. If you observe that putting a jar upside down over a candle makes the flame go out, you cannot explain this until you know the laws of chemistry, which reveals that fire needs oxygen to keep going. Use up the oxygen, and the flame goes out.
#
# But there’s a deeper meaning to “You can’t know how things end until you know how they began.” What really matters about death is the survival of consciousness. We observe the flame (the physical body) go out (die), but the mystery revolves around what happens to the non-physical part of ourselves. The things previously listed — mind soul, memory, personality, thoughts, feelings, etc. — are all experiences in consciousness.
#
# No matter how unique anyone’s life is, consciousness brings every human being together in the same place. Life is experienced in consciousness. Therefore, if we know how consciousness begins, we know how it ends. The opposite is also true. If we don’t know how consciousness begins, we can’t possibly know how (or if) it ends.
#
# Suddenly there is an opening for a true revelation. If consciousness has no beginning, then it has no end. In other words, the cause-and-effect model doesn’t work when it comes to consciousness. It can only be explained as existing on its own, independent of everything that does obey the rule of cause and effect.
#
# Can anything really be outside the realm of cause and effect? Absolutely. The universe sprang from a state preceding the Big Bang that offers no clue about matter, energy, space, or time. Without those things, there is no cause and effect. At the smallest scale of nature, the quantum field creates the physical universe through ripples of potential that emerge as subatomic particles and energy waves. There is no cause for this to happen; it just does. Existence has no cause, an obvious fact once you think about it.
#
# The New Age phrase, “Be here now,” isn’t a goal. You cannot help but be here now, since that’s the definition of existence. There are more controversial examples of things that have no cause. Many of your thoughts aren’t caused by the thoughts that preceded them. Thoughts spring up unpredictably from a state that isn’t a thought. It is a silent domain of possibilities.
#
# Here we are at the crux of the answer. If you don’t know how thoughts arise from total silence, you can’t possibly know how or if thoughts end. You already rely on the domain of silent, invisible possibilities all the time. You fetch memories from this domain, along with your vocabulary, your next desire, and your identity, which is nothing more than a constant process of filing away the experiences you identify with, calling them “me.”
#
# The nice thing about existence is that it can be relied upon even when you have no idea where it came from. “To be or not to be” is the wrong question. We are, period. Packaged in with being here now is consciousness. In a basic, irrefutable way, existence and consciousness go together. They are our home. We didn’t invent or create this home. It is our beginning and therefore our end, wrapped into one.
#
# Except that the words “beginning” and “end” are deceptive. There’s no reason to assume that existence had a beginning. Whatever you imagine as non-existence is a concept, and concepts, being mind-made, exist. Trying to nullify existence becomes circular. We are all at home here and now. We couldn’t be conscious without consciousness, the infinite, causeless, invisible, inconceivable origin of everything.
#
# Where do we go after we die? Nowhere in physical terms. We never leave home because there’s no alternative. Non-existence is a fantasy born of fear. I realize that making existence the same as consciousness sounds alien. I’ve tried to state the argument in simple statements that anyone is free to ponder. The answer has to be personal. You have to look at what life is, here and now, to gain anything like a stable set of conclusions. Explore what it is like to be at home, and you will realize that you can never leave home. A new worldview emerges if you look deep enough.

# %%
print("\033[92mAFTER: ")
print("\033[97mLength:", len(result[0]))
print(result[0])
# Out:
# AFTER:
# Length: 1561
# If you do not know how thoughts arise from total silence, you cannot possibly know how or if thoughts end. If we do not know how consciousness begins, we cannot possibly know how (or if) it ends. In place of religious certainty, modern people face death, not only with fear, doubt, dread, and foreboding but without a shred of empirical evidence about what happens after death. But there is a deeper meaning to “You cannot know how things end until you know how they began.” The things previously listed — mind soul, memory, personality, thoughts, feelings, etc. — are all experiences in consciousness. Therefore, if we know how consciousness begins, we know how it ends. In doing so it logically follows that when the physical body dies, in all likelihood the immaterial aspects of being human — mind soul, memory personality, thoughts, feelings, etc. — are extinguished at the same time. You cannot know how things end until you know how they began. “I will know what happens when it happens” is a good working attitude, but let us see if there is a better way. Despite all of its advances, science has stripped away any reassurances about life after death, and most people in the modern world accept the scientific model. If you observe that putting a jar upside down over a candle makes the flame go out, you cannot explain this until you know the laws of chemistry, which reveals that fire needs oxygen to keep going. We observe the flame (the physical body) go out (die), but the mystery revolves around what happens to the non-physical part of ourselves.

# %% [markdown]
# # Result Comparation and Evaluation

# %%
ROUGE = Rouge()

# %% [markdown]
# > The summary of the text below was obtained from:
# https://www.scribbr.com/text-summarizer/

# %%
reference = """
Religion and spirituality exist to reassure us about dying, as fear of death is universal but hidden from view in daily life. These traditions offer hope that something good or better than nothing happens after death. However, science has stripped away any reassurances about life after death, leading most people in the modern world to accept the scientific model. This model logically assumes that when the physical body dies, immaterial aspects of being human, such as the mind soul, memory, personality, thoughts, and feelings, are extinguished simultaneously.

This set of beliefs lacks proof, in the form of facts, data, and information. Modern people face death with fear, doubt, dread, and foreboding without empirical evidence about what happens after death. Both religious/spiritual and scientific worldviews amount to stories built around assumptions that can't be proven. When asked where we go after we die, the two main stories are hollow and confront a mystery that refuses to reveal its secrets.

A better way to approach death is to understand how consciousness begins and ends. The survival of consciousness is what really matters about death, as it brings every human being together in the same place. If we know how consciousness begins, we know how it ends, and the opposite is also true. If consciousness has no beginning, then it has no end. In other words, the cause-and-effect model doesn't work when it comes to consciousness.
"""

# %%
len(reference)
# Out:
# 1454

# %%
ROUGE.get_scores(result[0], reference)
# Out:
# [{'rouge-1': {'r': 0.4968152866242038,
#    'p': 0.4936708860759494,
#    'f': 0.49523809023814563},
#   'rouge-2': {'r': 0.23214285714285715,
#    'p': 0.22807017543859648,
#    'f': 0.23008849057561293},
#   'rouge-l': {'r': 0.4713375796178344,
#    'p': 0.46835443037974683,
#    'f': 0.46984126484132027}}]

# %% [markdown]
# > In conclusion, the evaluation of the model's performance reveals promising results across various Recall-Oriented Understudy for Gisting Evaluation (ROUGE) metrics. Specifically, the ROUGE-1 score stands at 0.6879, indicating a strong ability to capture individual words and unigrams, which is well above the threshold for a good score (0.5). The ROUGE-2 score of 0.4107 also reflects a solid performance in identifying pairs of words or bigrams, falling within the good range. Additionally, the ROUGE-L score of 0.6561 demonstrates effective alignment with the longest common subsequence between machine-generated and human reference summaries.

# %% [markdown]
# > While these ROUGE scores highlight the model's capacity for summarization, it is important to note that they do not fully account for semantic or syntactic quality. Therefore, although the model exhibits strong ROUGE metrics, further evaluation using additional metrics and human assessment is essential for a comprehensive understanding of its effectiveness in summarization tasks.
